# %% [markdown]
# # **Loading the Data**
# The data is present in a google drive folder, we need to load that data in colab. For that, we need to upload that data to our own google drive (maybe adding a shortcut of that data file to our drive, our downloading it and uploading it)

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
PATH_OF_DATA= '/content/gdrive/"My Drive"/ES_FaceMatch_Dataset'
# !ls {PATH_OF_DATA}

ROOT_DIR = 'gdrive/My Drive/ES_FaceMatch_Dataset'
IMG_DIR = 'dataset_images'
TRAIN_DIR = 'train.csv'
TEST_DIR = 'test.csv'
ZIP_FILE_DIR = '/content/gdrive/My Drive/images.zip'
# Out:
# dataset_images	test.csv  train.csv

# %%
import os 
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# # **Create a custom Data Class**
# Use a custom PyTorch data object - for each image pair since we need to load a pair of images with labels.

# %%
import pandas as pd
import numpy as np
from skimage import io
import skimage.transform
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, utils

# Defining a custom PyTorch Dataset Class to represent a pair of images
class imagePairs(torch.utils.data.Dataset):
    def __init__(self, root_dir, csv_file_dir, img_dir, transform = None):
        super(imagePairs, self).__init__()
        
        self.csv_file = pd.read_csv(os.path.join(root_dir, csv_file_dir))
        self.img_dir = img_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.csv_file)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img1_names = os.path.join(self.img_dir,self.csv_file.iloc[idx, 0])
        img2_names = os.path.join(self.img_dir, self.csv_file.iloc[idx, 1])
        
        # imread returns the numpy array of RGB values for the image. Shape = (H,W,3)
        image1 = io.imread(img1_names)
        image2 = io.imread(img2_names)
        label = self.csv_file.iloc[idx, 2]
        label = np.array([label])
        label = label.reshape(-1)
        
        sample = (image1, image2, label)

        if self.transform:
            sample = self.transform(sample)

        return sample

# Defining Image transforms - Image Preprocessing

# Rescaling Pair of Images together
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]

        h, w = image1.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        image1 = skimage.transform.resize(image1, (new_h, new_w))
        
        
        h, w = image2.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        image2 = skimage.transform.resize(image2, (new_h, new_w))

        return (image1, image2, sample[2])


class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = torch.randint(0, h - new_h)
        left = torch.randint(0, w - new_w)

        image1 = image1[top: top + new_h, left: left + new_w]
        image2 = image2[top: top + new_h, left: left + new_w]

        return (image1, image2, sample[2])

class Normalize(object):
    def __init__(self, mean = 127.5, std = 128.0):
        self.mean = mean
        self.std = std
    def __call__(self, sample):
        image1, image2, label = sample[0], sample[1], sample[2]
        image1 = (image1-self.mean)/self.std
        image2 = (image2-self.mean)/self.std
        return (image1, image2, label)

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image1, image2, label = sample[0], sample[1], sample[2]

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C x H x W
        image1 = image1.transpose((2, 0, 1))
        image2 = image2.transpose((2, 0, 1))
        return (torch.tensor(image1.copy(), dtype = torch.float32).contiguous(),
                torch.tensor(image2.copy(), dtype = torch.float32).contiguous(),
                torch.tensor(label, dtype = torch.long).contiguous())

# %%
# !unzip '/content/gdrive/My Drive/images.zip' -d '/content/cropped'

# %%
trainset = imagePairs(root_dir = ROOT_DIR, csv_file_dir= TRAIN_DIR,
                      img_dir = '/content/cropped', 
                      transform = transforms.Compose([Normalize(),ToTensor()]))

# %%
df = pd.read_csv(os.path.join(ROOT_DIR, TRAIN_DIR))
pos = df.iloc[:,2].sum()/len(df)
print(f"Positive Datapoints % = {pos}")
# Out:
# Positive Datapoints % = 0.36609942718568383

# %% [markdown]
# # Viewing Images in the Dataset

# %%
def imshow(image):
    if isinstance(image, torch.Tensor):
        image = (((image.numpy()*128)+127.5).transpose((1,2,0))).astype("int64")
    plt.imshow(image)
    plt.axis("off")
    plt.show()

i = np.random.randint(low = 0, high = 23912)
print(f"{i:=}")
print(trainset[i][2])
imshow(trainset[i][0])
imshow(trainset[i][1])
# Out:
# 23855
# tensor([0])

# %%
batch_size = 64
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True)

# %%
# Install PyTorch Facenet extension for Face Recognition Tasks
# !pip install facenet-pytorch
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.5.2-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 12.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from facenet-pytorch) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from facenet-pytorch) (2.23.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from facenet-pytorch) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from facenet-pytorch) (0.10.0+cu111)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->facenet-pytorch) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->facenet-pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->facenet-pytorch) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->facenet-pytorch) (1.24.3)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->facenet-pytorch) (1.9.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchvision->facenet-pytorch) (3.7.4.3)
# Installing collected packages: facenet-pytorch
# Successfully installed facenet-pytorch-2.5.2

# %% [markdown]
# # Defining the Model
# 0. **MTCNN** - Used for Data Pre-processing, our data is "noisy", for facial recognition, we only need faces of people, but our images contain lot of background as well. This is a pre-trained intelligent algorithm, which recognizes faces in an image and intelligently crops the image to only include the facial region of a person to help us in facial recognition task and reduces the unnnecessary information in the images
# 1. **Pre-trained ResNet** - Our CNN Layer, takes in images as input, outputs vector embeddings of that image
# 2. **Neural Tensor Network (NTN)** - Takes in as input the vector embeddings of the two image pairs being compared and outputs a $K$ dimensional **similarity score vector** ($K$ is a hyperparameter) which stores raw similarity scores between the image pair. <a href = "https://proceedings.neurips.cc/paper/2013/file/b337e84de8752b27eda3a12363109e80-Paper.pdf">Neural Tensor Network paper</a>
# 3. **Feedforward Neural Network (FFNN)** - Vanilla Neural Networks which take in as input, the output of the NTN Layer and produces a 2 dimensional output of same person/not-same-person

# %%
# Defining the Neural Tensor Network Layer as a Separate Class of Itself
class NTNLayer(torch.nn.Module):
    def __init__(self, output_layer_dim):
        """
        :param: d: Input Dimension of the NTN - i.e Dimension of the Graph/ Node Embeddings
        :param: k: Output Dimension of the NTN - No. of Similarity Scores to output
        """
        super(NTNLayer, self).__init__()
        self.d = 512 # Input Dimension of the NTN
        self.k = output_layer_dim # Output dimension of the NTN 
        self.params()
        self.initializeParams()
    
    def params(self):
        self.W = torch.nn.Parameter(torch.Tensor(self.d,self.d,self.k))
        self.V = torch.nn.Parameter(torch.Tensor(self.k, 2*self.d))
        self.b = torch.nn.Parameter(torch.Tensor(self.k,1))

    def initializeParams(self): 
        torch.nn.init.kaiming_normal_(self.W, a=0.1, nonlinearity='leaky_relu')
        torch.nn.init.kaiming_normal_(self.V, a=0.1, nonlinearity='leaky_relu')
        torch.nn.init.kaiming_normal_(self.b, a=0.1, nonlinearity='leaky_relu')
        
    def forward(self, h1, h2):
        """Returns 'K' Rough Similarity Scores between the Pair of Images
        The Neural Tensor Network (NTN) outputs 'K' similarity scores where 'K' is a hyperparameter
        :param: h1 : Graph Embedding of Graph 1 - (B,D)
        :param: h2 : Graph Embedding of Graph 2 - (B,D)
        """
        B = h1.shape[0]
        scores = torch.mm(h1, self.W.view(self.d, -1)) # (B,D) x (D, K*D) -> (B, K*D)
        scores = scores.view(B,self.d,self.k) # (B,K*D) -> (B,D,K)
        scores = (scores*h2.unsqueeze(-1)).sum(dim=1) # (B,D,K) * (B,D,1) -> (B,K)
        
        concatenated_rep = torch.cat((h1, h2), dim=1) # (B,2D)
        scores = scores + torch.mm(concatenated_rep, self.V.t()) # (B,2D) x (2D,K) -> (B,K)
        scores = scores + self.b.t() # (B,K) + (1,K) = (B,K)
        
        leaky_relu = torch.nn.LeakyReLU(negative_slope = 0.1)
        scores = leaky_relu(scores)
        return scores

# %%
from facenet_pytorch import InceptionResnetV1
import torch.nn.functional as F

class Flatten(torch.nn.Module):
        def __init__(self):
            super(Flatten, self).__init__()
            
        def forward(self, x):
            x = x.view(x.size(0), -1)
            return x
class normalize(torch.nn.Module):
    def __init__(self):
        super(normalize, self).__init__()
        
    def forward(self, x):
        x = F.normalize(x, p=2, dim=1)
        return x

# Decoder Part of the Model, including the ResNet CNN Layer begins
class Decoder(torch.nn.Module):
    def __init__(self, ntn_output_dim = 128):
        super(Decoder, self).__init__()
        self.ntn_output_dim = ntn_output_dim
        self.setupLayers()

    def setupResnet(self):
        # Downloading the Pre-trained ResNet CNN Layer
        model_ft = InceptionResnetV1(pretrained='vggface2', classify=False)

        # Listing all the final layers, which we are going to train
        layer_list = list(model_ft.children())[-5:]
        model_ft = torch.nn.Sequential(*list(model_ft.children())[:-5])

        # Since we just want to train final layers
        for param in model_ft.parameters():
            param.requires_grad = False
        
        # Re-attaching the final layers back to the model - automatically sets requires_grad = True
        model_ft.avgpool_1a = torch.nn.AdaptiveAvgPool2d(output_size=1)
        model_ft.last_linear = torch.nn.Sequential(Flatten(),
            torch.nn.Linear(in_features=1792, out_features=512, bias=False),
            normalize())
        
        return model_ft
    
    def setupLayers(self):
        # ResNet and Neural Tensor Network Layer
        self.resnet = self.setupResnet()
        self.NTN = NTNLayer(self.ntn_output_dim)
        
        # Linear Layers for the Final Output
        self.lin1 = torch.nn.Linear(self.ntn_output_dim,64)
        self.lin2 = torch.nn.Linear(64,32)
        self.lin3 = torch.nn.Linear(32,16)
        self.lin4 = torch.nn.Linear(16,8)
        self.lin5 = torch.nn.Linear(8,2)

    def FCNN(self, x):
        X = self.lin1(x)
        X = X.relu()
        X = self.lin2(X)
        X = X.relu() 
        X = self.lin3(X)
        X = X.relu()
        X = self.lin4(X)
        X = X.relu() 
        X = self.lin5(X)
        return X

    def rbfKernel(self, h1,h2):
        distance = h1-h2
        distance = torch.sum(distance*distance, dim = 1)
        return torch.exp(-distance).view(-1,1)

    def forward(self, X1, X2):
        # Passing input images through the ResNet to generate Image Embeddings
        h1 = self.resnet(X1)
        h2 = self.resnet(X2)

        # Passing the image embeddings via the NTN and the FCNN layer for predictions
        y_pred = self.NTN(h1, h2)
        y_pred = torch.cat((y_pred, self.rbfKernel(h1,h2)), dim=1)
        y_pred = self.FCNN(y_pred)

        return y_pred

# %% [markdown]
# # Training Begins

# %%
def evaluate(loader):
    decoder.eval()
    correct = 0
    with torch.no_grad():
        for batch in loader:
            # Passing it via final encoder to get predictions
            y_pred = decoder(batch[0].to(device), batch[1].to(device))
            y_pred = y_pred.argmax(dim=1)
            correct += (y_pred == batch[2].view(-1).to(device)).sum()
            
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
    return correct / len(df)

# %%
def train_batch(batch):
    # Passing it via final decoder to get predictions
    y_pred = decoder(batch[0].to(device), batch[1].to(device))
    
    loss = criterion(y_pred, batch[2].view(-1).to(device))
    loss.backward()
    opt.step()
    return loss.item()

# %%
PATH_TO_MODEL = '/content/gdrive/My Drive/model.pth'

# %%
decoder = Decoder()
# Choose whatever GPU device number you want
decoder.load_state_dict(torch.load(PATH_TO_MODEL, map_location="cuda:0"))
decoder.to(device)

# %%
class_weights = [pos, 1-pos]
class_weights = torch.tensor(class_weights,dtype=torch.float).to(device)
criterion = torch.nn.CrossEntropyLoss(weight = class_weights, reduction = 'mean')
opt = torch.optim.AdamW(decoder.parameters(), lr = 0.005, weight_decay = 1e-5)

epochs = 3
for epoch in range(epochs):
    for i, batch in enumerate(trainloader):
        # Setting all the gradients to zero to prevent carry forward
        opt.zero_grad()
        decoder.train()
        loss = train_batch(batch)
        print(f'Epoch: {epoch+1:2d} | Iteration {i:3d}/{len(trainloader)} | Batch Loss = {loss:.6f}')
        
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    #print(f"Epoch: {epoch+1:2d} | Accuracy: {evaluate(trainloader):.6f}")
# Out:
# Epoch:  1 | Iteration   0/374 | Batch Loss = 0.487134
# Epoch:  1 | Iteration   1/374 | Batch Loss = 0.290268
# Epoch:  1 | Iteration   2/374 | Batch Loss = 0.192345
# Epoch:  1 | Iteration   3/374 | Batch Loss = 0.240294
# Epoch:  1 | Iteration   4/374 | Batch Loss = 0.311862
# Epoch:  1 | Iteration   5/374 | Batch Loss = 0.349160
# Epoch:  1 | Iteration   6/374 | Batch Loss = 0.204326
# Epoch:  1 | Iteration   7/374 | Batch Loss = 0.223112
# Epoch:  1 | Iteration   8/374 | Batch Loss = 0.227949
# Epoch:  1 | Iteration   9/374 | Batch Loss = 0.241237
# Epoch:  1 | Iteration  10/374 | Batch Loss = 0.212167
# Epoch:  1 | Iteration  11/374 | Batch Loss = 0.281388
# Epoch:  1 | Iteration  12/374 | Batch Loss = 0.282679
# Epoch:  1 | Iteration  13/374 | Batch Loss = 0.456480
# Epoch:  1 | Iteration  14/374 | Batch Loss = 0.263491
# Epoch:  1 | Iteration  15/374 | Batch Loss = 0.233324
# Epoch:  1 | Iteration  16/374 | Batch Loss = 0.370815
# Epoch:  1 | Iteration  17/374 | Batch Loss = 0.250122
# Epoch:  1 | Iteration  18/374 | Batch Loss = 0.320560
# Epoch:  1 | Iteration  19/374 | Batch Loss = 0.199446
# Epoch:  1 | Iteration  20/374 | Batch Loss = 0.233229
# Epoch:  1 | Iteration  21/374 | Batch Loss = 0.258395
# Epoch:  1 | Iteration  22/374 | Batch Loss = 0.265965
# Epoch:  1 | Iteration  23/374 | Batch Loss = 0.286734
# Epoch:  1 | Iteration  24/374 | Batch Loss = 0.316722
# Epoch:  1 | Iteration  25/374 | Batch Loss = 0.194939
# Epoch:  1 | Iteration  26/374 | Batch Loss = 0.182395
# Epoch:  1 | Iteration  27/374 | Batch Loss = 0.243982
# Epoch:  1 | Iteration  28/374 | Batch Loss = 0.347577
# Epoch:  1 | Iteration  29/374 | Batch Loss = 0.218731
# Epoch:  1 | Iteration  30/374 | Batch Loss = 0.298045
# Epoch:  1 | Iteration  31/374 | Batch Loss = 0.295801
# Epoch:  1 | Iteration  32/374 | Batch Loss = 0.223280
# Epoch:  1 | Iteration  33/374 | Batch Loss = 0.295885
# Epoch:  1 | Iteration  34/374 | Batch Loss = 0.148741
# Epoch:  1 | Iteration  35/374 | Batch Loss = 0.260785
# Epoch:  1 | Iteration  36/374 | Batch Loss = 0.475033
# Epoch:  1 | Iteration  37/374 | Batch Loss = 0.217145
# Epoch:  1 | Iteration  38/374 | Batch Loss = 0.307425
# Epoch:  1 | Iteration  39/374 | Batch Loss = 0.295911
# Epoch:  1 | Iteration  40/374 | Batch Loss = 0.356046
# Epoch:  1 | Iteration  41/374 | Batch Loss = 0.168972
# Epoch:  1 | Iteration  42/374 | Batch Loss = 0.242912
# Epoch:  1 | Iteration  43/374 | Batch Loss = 0.233590
# Epoch:  1 | Iteration  44/374 | Batch Loss = 0.299649
# Epoch:  1 | Iteration  45/374 | Batch Loss = 0.337233
# Epoch:  1 | Iteration  46/374 | Batch Loss = 0.166340
# Epoch:  1 | Iteration  47/374 | Batch Loss = 0.220010
# Epoch:  1 | Iteration  48/374 | Batch Loss = 0.264587
# Epoch:  1 | Iteration  49/374 | Batch Loss = 0.194726
# Epoch:  1 | Iteration  50/374 | Batch Loss = 0.360672
# Epoch:  1 | Iteration  51/374 | Batch Loss = 0.314932
# Epoch:  1 | Iteration  52/374 | Batch Loss = 0.241080
# Epoch:  1 | Iteration  53/374 | Batch Loss = 0.221990
# Epoch:  1 | Iteration  54/374 | Batch Loss = 0.311048
# Epoch:  1 | Iteration  55/374 | Batch Loss = 0.256037
# Epoch:  1 | Iteration  56/374 | Batch Loss = 0.249038
# Epoch:  1 | Iteration  57/374 | Batch Loss = 0.232539
# Epoch:  1 | Iteration  58/374 | Batch Loss = 0.173241
# Epoch:  1 | Iteration  59/374 | Batch Loss = 0.157408
# Epoch:  1 | Iteration  60/374 | Batch Loss = 0.162427
# Epoch:  1 | Iteration  61/374 | Batch Loss = 0.175083
# Epoch:  1 | Iteration  62/374 | Batch Loss = 0.271249
# Epoch:  1 | Iteration  63/374 | Batch Loss = 0.268594
# Epoch:  1 | Iteration  64/374 | Batch Loss = 0.261351
# Epoch:  1 | Iteration  65/374 | Batch Loss = 0.177297
# Epoch:  1 | Iteration  66/374 | Batch Loss = 0.167305
# Epoch:  1 | Iteration  67/374 | Batch Loss = 0.121486
# Epoch:  1 | Iteration  68/374 | Batch Loss = 0.167947
# Epoch:  1 | Iteration  69/374 | Batch Loss = 0.122116
# Epoch:  1 | Iteration  70/374 | Batch Loss = 0.286294
# Epoch:  1 | Iteration  71/374 | Batch Loss = 0.279982
# Epoch:  1 | Iteration  72/374 | Batch Loss = 0.220831
# Epoch:  1 | Iteration  73/374 | Batch Loss = 0.332482
# Epoch:  1 | Iteration  74/374 | Batch Loss = 0.173775
# Epoch:  1 | Iteration  75/374 | Batch Loss = 0.230712
# Epoch:  1 | Iteration  76/374 | Batch Loss = 0.144796
# Epoch:  1 | Iteration  77/374 | Batch Loss = 0.159943
# Epoch:  1 | Iteration  78/374 | Batch Loss = 0.259550
# Epoch:  1 | Iteration  79/374 | Batch Loss = 0.325862
# Epoch:  1 | Iteration  80/374 | Batch Loss = 0.198649
# Epoch:  1 | Iteration  81/374 | Batch Loss = 0.371167
# Epoch:  1 | Iteration  82/374 | Batch Loss = 0.204479
# Epoch:  1 | Iteration  83/374 | Batch Loss = 0.250767
# Epoch:  1 | Iteration  84/374 | Batch Loss = 0.356397
# Epoch:  1 | Iteration  85/374 | Batch Loss = 0.214018
# Epoch:  1 | Iteration  86/374 | Batch Loss = 0.376947
# Epoch:  1 | Iteration  87/374 | Batch Loss = 0.219880
# Epoch:  1 | Iteration  88/374 | Batch Loss = 0.263069
# Epoch:  1 | Iteration  89/374 | Batch Loss = 0.288774
# Epoch:  1 | Iteration  90/374 | Batch Loss = 0.235830
# Epoch:  1 | Iteration  91/374 | Batch Loss = 0.276154
# Epoch:  1 | Iteration  92/374 | Batch Loss = 0.174075
# Epoch:  1 | Iteration  93/374 | Batch Loss = 0.362520
# Epoch:  1 | Iteration  94/374 | Batch Loss = 0.179857
# Epoch:  1 | Iteration  95/374 | Batch Loss = 0.188452
# Epoch:  1 | Iteration  96/374 | Batch Loss = 0.231059
# Epoch:  1 | Iteration  97/374 | Batch Loss = 0.264475
# Epoch:  1 | Iteration  98/374 | Batch Loss = 0.150044
# Epoch:  1 | Iteration  99/374 | Batch Loss = 0.284197
# Epoch:  1 | Iteration 100/374 | Batch Loss = 0.360496
# Epoch:  1 | Iteration 101/374 | Batch Loss = 0.164256
# Epoch:  1 | Iteration 102/374 | Batch Loss = 0.225641
# Epoch:  1 | Iteration 103/374 | Batch Loss = 0.205391
# Epoch:  1 | Iteration 104/374 | Batch Loss = 0.215268
# Epoch:  1 | Iteration 105/374 | Batch Loss = 0.313610
# Epoch:  1 | Iteration 106/374 | Batch Loss = 0.216078
# Epoch:  1 | Iteration 107/374 | Batch Loss = 0.187951
# Epoch:  1 | Iteration 108/374 | Batch Loss = 0.392718
# Epoch:  1 | Iteration 109/374 | Batch Loss = 0.238112
# Epoch:  1 | Iteration 110/374 | Batch Loss = 0.313040
# Epoch:  1 | Iteration 111/374 | Batch Loss = 0.282643
# Epoch:  1 | Iteration 112/374 | Batch Loss = 0.199059
# Epoch:  1 | Iteration 113/374 | Batch Loss = 0.191583
# Epoch:  1 | Iteration 114/374 | Batch Loss = 0.337578
# Epoch:  1 | Iteration 115/374 | Batch Loss = 0.254248
# Epoch:  1 | Iteration 116/374 | Batch Loss = 0.286405
# Epoch:  1 | Iteration 117/374 | Batch Loss = 0.236338
# Epoch:  1 | Iteration 118/374 | Batch Loss = 0.363379
# Epoch:  1 | Iteration 119/374 | Batch Loss = 0.383240
# Epoch:  1 | Iteration 120/374 | Batch Loss = 0.293816
# Epoch:  1 | Iteration 121/374 | Batch Loss = 0.246493
# Epoch:  1 | Iteration 122/374 | Batch Loss = 0.202228
# Epoch:  1 | Iteration 123/374 | Batch Loss = 0.252114
# Epoch:  1 | Iteration 124/374 | Batch Loss = 0.241006
# Epoch:  1 | Iteration 125/374 | Batch Loss = 0.264774
# Epoch:  1 | Iteration 126/374 | Batch Loss = 0.326329
# Epoch:  1 | Iteration 127/374 | Batch Loss = 0.395108
# Epoch:  1 | Iteration 128/374 | Batch Loss = 0.215503
# Epoch:  1 | Iteration 129/374 | Batch Loss = 0.176730
# Epoch:  1 | Iteration 130/374 | Batch Loss = 0.226582
# Epoch:  1 | Iteration 131/374 | Batch Loss = 0.211137
# Epoch:  1 | Iteration 132/374 | Batch Loss = 0.273714
# Epoch:  1 | Iteration 133/374 | Batch Loss = 0.210668
# Epoch:  1 | Iteration 134/374 | Batch Loss = 0.323074
# Epoch:  1 | Iteration 135/374 | Batch Loss = 0.251701
# Epoch:  1 | Iteration 136/374 | Batch Loss = 0.205443
# Epoch:  1 | Iteration 137/374 | Batch Loss = 0.312030
# Epoch:  1 | Iteration 138/374 | Batch Loss = 0.215763
# Epoch:  1 | Iteration 139/374 | Batch Loss = 0.215159
# Epoch:  1 | Iteration 140/374 | Batch Loss = 0.248375
# Epoch:  1 | Iteration 141/374 | Batch Loss = 0.382427
# Epoch:  1 | Iteration 142/374 | Batch Loss = 0.178671
# Epoch:  1 | Iteration 143/374 | Batch Loss = 0.291050
# Epoch:  1 | Iteration 144/374 | Batch Loss = 0.194658
# Epoch:  1 | Iteration 145/374 | Batch Loss = 0.158827
# Epoch:  1 | Iteration 146/374 | Batch Loss = 0.213252
# Epoch:  1 | Iteration 147/374 | Batch Loss = 0.204506
# Epoch:  1 | Iteration 148/374 | Batch Loss = 0.103231
# Epoch:  1 | Iteration 149/374 | Batch Loss = 0.357800
# Epoch:  1 | Iteration 150/374 | Batch Loss = 0.204739
# Epoch:  1 | Iteration 151/374 | Batch Loss = 0.118382
# Epoch:  1 | Iteration 152/374 | Batch Loss = 0.262545
# Epoch:  1 | Iteration 153/374 | Batch Loss = 0.248162
# Epoch:  1 | Iteration 154/374 | Batch Loss = 0.259440
# Epoch:  1 | Iteration 155/374 | Batch Loss = 0.259671
# Epoch:  1 | Iteration 156/374 | Batch Loss = 0.331769
# Epoch:  1 | Iteration 157/374 | Batch Loss = 0.207554
# Epoch:  1 | Iteration 158/374 | Batch Loss = 0.260722
# Epoch:  1 | Iteration 159/374 | Batch Loss = 0.322401
# Epoch:  1 | Iteration 160/374 | Batch Loss = 0.158122
# Epoch:  1 | Iteration 161/374 | Batch Loss = 0.211987
# Epoch:  1 | Iteration 162/374 | Batch Loss = 0.253748
# Epoch:  1 | Iteration 163/374 | Batch Loss = 0.194684
# Epoch:  1 | Iteration 164/374 | Batch Loss = 0.211125
# Epoch:  1 | Iteration 165/374 | Batch Loss = 0.181593
# Epoch:  1 | Iteration 166/374 | Batch Loss = 0.259212
# Epoch:  1 | Iteration 167/374 | Batch Loss = 0.093868
# Epoch:  1 | Iteration 168/374 | Batch Loss = 0.321497
# Epoch:  1 | Iteration 169/374 | Batch Loss = 0.191401
# Epoch:  1 | Iteration 170/374 | Batch Loss = 0.256711
# Epoch:  1 | Iteration 171/374 | Batch Loss = 0.304953
# Epoch:  1 | Iteration 172/374 | Batch Loss = 0.266997
# Epoch:  1 | Iteration 173/374 | Batch Loss = 0.351261
# Epoch:  1 | Iteration 174/374 | Batch Loss = 0.191762
# Epoch:  1 | Iteration 175/374 | Batch Loss = 0.183832
# Epoch:  1 | Iteration 176/374 | Batch Loss = 0.231363
# Epoch:  1 | Iteration 177/374 | Batch Loss = 0.228333
# Epoch:  1 | Iteration 178/374 | Batch Loss = 0.224956
# Epoch:  1 | Iteration 179/374 | Batch Loss = 0.191528
# Epoch:  1 | Iteration 180/374 | Batch Loss = 0.207892
# Epoch:  1 | Iteration 181/374 | Batch Loss = 0.325597
# Epoch:  1 | Iteration 182/374 | Batch Loss = 0.375657
# Epoch:  1 | Iteration 183/374 | Batch Loss = 0.227149
# Epoch:  1 | Iteration 184/374 | Batch Loss = 0.171174
# Epoch:  1 | Iteration 185/374 | Batch Loss = 0.285206
# Epoch:  1 | Iteration 186/374 | Batch Loss = 0.317455
# Epoch:  1 | Iteration 187/374 | Batch Loss = 0.215232
# Epoch:  1 | Iteration 188/374 | Batch Loss = 0.188877
# Epoch:  1 | Iteration 189/374 | Batch Loss = 0.222508
# Epoch:  1 | Iteration 190/374 | Batch Loss = 0.247833
# Epoch:  1 | Iteration 191/374 | Batch Loss = 0.211617
# Epoch:  1 | Iteration 192/374 | Batch Loss = 0.351473
# Epoch:  1 | Iteration 193/374 | Batch Loss = 0.315469
# Epoch:  1 | Iteration 194/374 | Batch Loss = 0.221625
# Epoch:  1 | Iteration 195/374 | Batch Loss = 0.214246
# Epoch:  1 | Iteration 196/374 | Batch Loss = 0.155376
# Epoch:  1 | Iteration 197/374 | Batch Loss = 0.139998
# Epoch:  1 | Iteration 198/374 | Batch Loss = 0.257844
# Epoch:  1 | Iteration 199/374 | Batch Loss = 0.240632
# Epoch:  1 | Iteration 200/374 | Batch Loss = 0.257318
# Epoch:  1 | Iteration 201/374 | Batch Loss = 0.209974
# Epoch:  1 | Iteration 202/374 | Batch Loss = 0.219182
# Epoch:  1 | Iteration 203/374 | Batch Loss = 0.242936
# Epoch:  1 | Iteration 204/374 | Batch Loss = 0.226249
# Epoch:  1 | Iteration 205/374 | Batch Loss = 0.275100
# Epoch:  1 | Iteration 206/374 | Batch Loss = 0.184081
# Epoch:  1 | Iteration 207/374 | Batch Loss = 0.396791
# Epoch:  1 | Iteration 208/374 | Batch Loss = 0.181632
# Epoch:  1 | Iteration 209/374 | Batch Loss = 0.216020
# Epoch:  1 | Iteration 210/374 | Batch Loss = 0.182705
# Epoch:  1 | Iteration 211/374 | Batch Loss = 0.271275
# Epoch:  1 | Iteration 212/374 | Batch Loss = 0.144753
# Epoch:  1 | Iteration 213/374 | Batch Loss = 0.211017
# Epoch:  1 | Iteration 214/374 | Batch Loss = 0.233345
# Epoch:  1 | Iteration 215/374 | Batch Loss = 0.192805
# Epoch:  1 | Iteration 216/374 | Batch Loss = 0.186478
# Epoch:  1 | Iteration 217/374 | Batch Loss = 0.178738
# Epoch:  1 | Iteration 218/374 | Batch Loss = 0.233074
# Epoch:  1 | Iteration 219/374 | Batch Loss = 0.242850
# Epoch:  1 | Iteration 220/374 | Batch Loss = 0.199049
# Epoch:  1 | Iteration 221/374 | Batch Loss = 0.366279
# Epoch:  1 | Iteration 222/374 | Batch Loss = 0.098258
# Epoch:  1 | Iteration 223/374 | Batch Loss = 0.139950
# Epoch:  1 | Iteration 224/374 | Batch Loss = 0.224402
# Epoch:  1 | Iteration 225/374 | Batch Loss = 0.220649
# Epoch:  1 | Iteration 226/374 | Batch Loss = 0.410606
# Epoch:  1 | Iteration 227/374 | Batch Loss = 0.158256
# Epoch:  1 | Iteration 228/374 | Batch Loss = 0.336091
# Epoch:  1 | Iteration 229/374 | Batch Loss = 0.224229
# Epoch:  1 | Iteration 230/374 | Batch Loss = 0.177232
# Epoch:  1 | Iteration 231/374 | Batch Loss = 0.217470
# Epoch:  1 | Iteration 232/374 | Batch Loss = 0.256130
# Epoch:  1 | Iteration 233/374 | Batch Loss = 0.173765
# Epoch:  1 | Iteration 234/374 | Batch Loss = 0.263706
# Epoch:  1 | Iteration 235/374 | Batch Loss = 0.225543
# Epoch:  1 | Iteration 236/374 | Batch Loss = 0.263370
# Epoch:  1 | Iteration 237/374 | Batch Loss = 0.176667
# Epoch:  1 | Iteration 238/374 | Batch Loss = 0.313917
# Epoch:  1 | Iteration 239/374 | Batch Loss = 0.179036
# Epoch:  1 | Iteration 240/374 | Batch Loss = 0.187016
# Epoch:  1 | Iteration 241/374 | Batch Loss = 0.254920
# Epoch:  1 | Iteration 242/374 | Batch Loss = 0.292537
# Epoch:  1 | Iteration 243/374 | Batch Loss = 0.154652
# Epoch:  1 | Iteration 244/374 | Batch Loss = 0.201431
# Epoch:  1 | Iteration 245/374 | Batch Loss = 0.194774
# Epoch:  1 | Iteration 246/374 | Batch Loss = 0.119596
# Epoch:  1 | Iteration 247/374 | Batch Loss = 0.184063
# Epoch:  1 | Iteration 248/374 | Batch Loss = 0.327037
# Epoch:  1 | Iteration 249/374 | Batch Loss = 0.167217
# Epoch:  1 | Iteration 250/374 | Batch Loss = 0.118954
# Epoch:  1 | Iteration 251/374 | Batch Loss = 0.245284
# Epoch:  1 | Iteration 252/374 | Batch Loss = 0.246170
# Epoch:  1 | Iteration 253/374 | Batch Loss = 0.145002
# Epoch:  1 | Iteration 254/374 | Batch Loss = 0.218283
# Epoch:  1 | Iteration 255/374 | Batch Loss = 0.152715
# Epoch:  1 | Iteration 256/374 | Batch Loss = 0.338200
# Epoch:  1 | Iteration 257/374 | Batch Loss = 0.098062
# Epoch:  1 | Iteration 258/374 | Batch Loss = 0.141812
# Epoch:  1 | Iteration 259/374 | Batch Loss = 0.215781
# Epoch:  1 | Iteration 260/374 | Batch Loss = 0.298973
# Epoch:  1 | Iteration 261/374 | Batch Loss = 0.153934
# Epoch:  1 | Iteration 262/374 | Batch Loss = 0.368314
# Epoch:  1 | Iteration 263/374 | Batch Loss = 0.209952
# Epoch:  1 | Iteration 264/374 | Batch Loss = 0.163849
# Epoch:  1 | Iteration 265/374 | Batch Loss = 0.238851
# Epoch:  1 | Iteration 266/374 | Batch Loss = 0.238748
# Epoch:  1 | Iteration 267/374 | Batch Loss = 0.200906
# Epoch:  1 | Iteration 268/374 | Batch Loss = 0.204116
# Epoch:  1 | Iteration 269/374 | Batch Loss = 0.160224
# Epoch:  1 | Iteration 270/374 | Batch Loss = 0.198287
# Epoch:  1 | Iteration 271/374 | Batch Loss = 0.335860
# Epoch:  1 | Iteration 272/374 | Batch Loss = 0.257171
# Epoch:  1 | Iteration 273/374 | Batch Loss = 0.186100
# Epoch:  1 | Iteration 274/374 | Batch Loss = 0.186434
# Epoch:  1 | Iteration 275/374 | Batch Loss = 0.415483
# Epoch:  1 | Iteration 276/374 | Batch Loss = 0.175681
# Epoch:  1 | Iteration 277/374 | Batch Loss = 0.107475
# Epoch:  1 | Iteration 278/374 | Batch Loss = 0.206664
# Epoch:  1 | Iteration 279/374 | Batch Loss = 0.366938
# Epoch:  1 | Iteration 280/374 | Batch Loss = 0.241402
# Epoch:  1 | Iteration 281/374 | Batch Loss = 0.183814
# Epoch:  1 | Iteration 282/374 | Batch Loss = 0.193106
# Epoch:  1 | Iteration 283/374 | Batch Loss = 0.211419
# Epoch:  1 | Iteration 284/374 | Batch Loss = 0.264083
# Epoch:  1 | Iteration 285/374 | Batch Loss = 0.310430
# Epoch:  1 | Iteration 286/374 | Batch Loss = 0.280831
# Epoch:  1 | Iteration 287/374 | Batch Loss = 0.202021
# Epoch:  1 | Iteration 288/374 | Batch Loss = 0.243625
# Epoch:  1 | Iteration 289/374 | Batch Loss = 0.269563
# Epoch:  1 | Iteration 290/374 | Batch Loss = 0.273352
# Epoch:  1 | Iteration 291/374 | Batch Loss = 0.273877
# Epoch:  1 | Iteration 292/374 | Batch Loss = 0.386972
# Epoch:  1 | Iteration 293/374 | Batch Loss = 0.164547
# Epoch:  1 | Iteration 294/374 | Batch Loss = 0.172942
# Epoch:  1 | Iteration 295/374 | Batch Loss = 0.314561
# Epoch:  1 | Iteration 296/374 | Batch Loss = 0.179096
# Epoch:  1 | Iteration 297/374 | Batch Loss = 0.178463
# Epoch:  1 | Iteration 298/374 | Batch Loss = 0.172907
# Epoch:  1 | Iteration 299/374 | Batch Loss = 0.238102
# Epoch:  1 | Iteration 300/374 | Batch Loss = 0.458868
# Epoch:  1 | Iteration 301/374 | Batch Loss = 0.284580
# Epoch:  1 | Iteration 302/374 | Batch Loss = 0.179227
# Epoch:  1 | Iteration 303/374 | Batch Loss = 0.198830
# Epoch:  1 | Iteration 304/374 | Batch Loss = 0.287692
# Epoch:  1 | Iteration 305/374 | Batch Loss = 0.218095
# Epoch:  1 | Iteration 306/374 | Batch Loss = 0.246751
# Epoch:  1 | Iteration 307/374 | Batch Loss = 0.211058
# Epoch:  1 | Iteration 308/374 | Batch Loss = 0.356226
# Epoch:  1 | Iteration 309/374 | Batch Loss = 0.332016
# Epoch:  1 | Iteration 310/374 | Batch Loss = 0.227946
# Epoch:  1 | Iteration 311/374 | Batch Loss = 0.192901
# Epoch:  1 | Iteration 312/374 | Batch Loss = 0.244043
# Epoch:  1 | Iteration 313/374 | Batch Loss = 0.229642
# Epoch:  1 | Iteration 314/374 | Batch Loss = 0.260183
# Epoch:  1 | Iteration 315/374 | Batch Loss = 0.290735
# Epoch:  1 | Iteration 316/374 | Batch Loss = 0.226666
# Epoch:  1 | Iteration 317/374 | Batch Loss = 0.266471
# Epoch:  1 | Iteration 318/374 | Batch Loss = 0.177567
# Epoch:  1 | Iteration 319/374 | Batch Loss = 0.316912
# Epoch:  1 | Iteration 320/374 | Batch Loss = 0.211048
# Epoch:  1 | Iteration 321/374 | Batch Loss = 0.169812
# Epoch:  1 | Iteration 322/374 | Batch Loss = 0.242351
# Epoch:  1 | Iteration 323/374 | Batch Loss = 0.192990
# Epoch:  1 | Iteration 324/374 | Batch Loss = 0.181436
# Epoch:  1 | Iteration 325/374 | Batch Loss = 0.210739
# Epoch:  1 | Iteration 326/374 | Batch Loss = 0.233310
# Epoch:  1 | Iteration 327/374 | Batch Loss = 0.257085
# Epoch:  1 | Iteration 328/374 | Batch Loss = 0.391966
# Epoch:  1 | Iteration 329/374 | Batch Loss = 0.277288
# Epoch:  1 | Iteration 330/374 | Batch Loss = 0.313221
# Epoch:  1 | Iteration 331/374 | Batch Loss = 0.209564
# Epoch:  1 | Iteration 332/374 | Batch Loss = 0.188163
# Epoch:  1 | Iteration 333/374 | Batch Loss = 0.206401
# Epoch:  1 | Iteration 334/374 | Batch Loss = 0.116260
# Epoch:  1 | Iteration 335/374 | Batch Loss = 0.292551
# Epoch:  1 | Iteration 336/374 | Batch Loss = 0.159126
# Epoch:  1 | Iteration 337/374 | Batch Loss = 0.211751
# Epoch:  1 | Iteration 338/374 | Batch Loss = 0.106146
# Epoch:  1 | Iteration 339/374 | Batch Loss = 0.326887
# Epoch:  1 | Iteration 340/374 | Batch Loss = 0.234612
# Epoch:  1 | Iteration 341/374 | Batch Loss = 0.322130
# Epoch:  1 | Iteration 342/374 | Batch Loss = 0.189350
# Epoch:  1 | Iteration 343/374 | Batch Loss = 0.163740
# Epoch:  1 | Iteration 344/374 | Batch Loss = 0.180294
# Epoch:  1 | Iteration 345/374 | Batch Loss = 0.294742
# Epoch:  1 | Iteration 346/374 | Batch Loss = 0.146946
# Epoch:  1 | Iteration 347/374 | Batch Loss = 0.220292
# Epoch:  1 | Iteration 348/374 | Batch Loss = 0.238862
# Epoch:  1 | Iteration 349/374 | Batch Loss = 0.163507
# Epoch:  1 | Iteration 350/374 | Batch Loss = 0.115374
# Epoch:  1 | Iteration 351/374 | Batch Loss = 0.222382
# Epoch:  1 | Iteration 352/374 | Batch Loss = 0.245712
# Epoch:  1 | Iteration 353/374 | Batch Loss = 0.253993
# Epoch:  1 | Iteration 354/374 | Batch Loss = 0.317075
# Epoch:  1 | Iteration 355/374 | Batch Loss = 0.308138
# Epoch:  1 | Iteration 356/374 | Batch Loss = 0.177732
# Epoch:  1 | Iteration 357/374 | Batch Loss = 0.123484
# Epoch:  1 | Iteration 358/374 | Batch Loss = 0.247415
# Epoch:  1 | Iteration 359/374 | Batch Loss = 0.228095
# Epoch:  1 | Iteration 360/374 | Batch Loss = 0.148691
# Epoch:  1 | Iteration 361/374 | Batch Loss = 0.254083
# Epoch:  1 | Iteration 362/374 | Batch Loss = 0.218496
# Epoch:  1 | Iteration 363/374 | Batch Loss = 0.177704
# Epoch:  1 | Iteration 364/374 | Batch Loss = 0.324549
# Epoch:  1 | Iteration 365/374 | Batch Loss = 0.244623
# Epoch:  1 | Iteration 366/374 | Batch Loss = 0.203949
# Epoch:  1 | Iteration 367/374 | Batch Loss = 0.238694
# Epoch:  1 | Iteration 368/374 | Batch Loss = 0.303357
# Epoch:  1 | Iteration 369/374 | Batch Loss = 0.251799
# Epoch:  1 | Iteration 370/374 | Batch Loss = 0.204498
# Epoch:  1 | Iteration 371/374 | Batch Loss = 0.170004
# Epoch:  1 | Iteration 372/374 | Batch Loss = 0.355339
# Epoch:  1 | Iteration 373/374 | Batch Loss = 0.166618
# Epoch:  2 | Iteration   0/374 | Batch Loss = 0.071043
# Epoch:  2 | Iteration   1/374 | Batch Loss = 0.140952
# Epoch:  2 | Iteration   2/374 | Batch Loss = 0.150008
# Epoch:  2 | Iteration   3/374 | Batch Loss = 0.213156
# Epoch:  2 | Iteration   4/374 | Batch Loss = 0.184730
# Epoch:  2 | Iteration   5/374 | Batch Loss = 0.160810
# Epoch:  2 | Iteration   6/374 | Batch Loss = 0.147309
# Epoch:  2 | Iteration   7/374 | Batch Loss = 0.120298
# Epoch:  2 | Iteration   8/374 | Batch Loss = 0.155609
# Epoch:  2 | Iteration   9/374 | Batch Loss = 0.211876
# Epoch:  2 | Iteration  10/374 | Batch Loss = 0.128484
# Epoch:  2 | Iteration  11/374 | Batch Loss = 0.174033
# Epoch:  2 | Iteration  12/374 | Batch Loss = 0.206645
# Epoch:  2 | Iteration  13/374 | Batch Loss = 0.188600
# Epoch:  2 | Iteration  14/374 | Batch Loss = 0.118977
# Epoch:  2 | Iteration  15/374 | Batch Loss = 0.225660
# Epoch:  2 | Iteration  16/374 | Batch Loss = 0.145941
# Epoch:  2 | Iteration  17/374 | Batch Loss = 0.116472
# Epoch:  2 | Iteration  18/374 | Batch Loss = 0.317769
# Epoch:  2 | Iteration  19/374 | Batch Loss = 0.163182
# Epoch:  2 | Iteration  20/374 | Batch Loss = 0.147827
# Epoch:  2 | Iteration  21/374 | Batch Loss = 0.075267
# Epoch:  2 | Iteration  22/374 | Batch Loss = 0.257665
# Epoch:  2 | Iteration  23/374 | Batch Loss = 0.127210
# Epoch:  2 | Iteration  24/374 | Batch Loss = 0.135691
# Epoch:  2 | Iteration  25/374 | Batch Loss = 0.153151
# Epoch:  2 | Iteration  26/374 | Batch Loss = 0.440357
# Epoch:  2 | Iteration  27/374 | Batch Loss = 0.452568
# Epoch:  2 | Iteration  28/374 | Batch Loss = 0.231324
# Epoch:  2 | Iteration  29/374 | Batch Loss = 0.132608
# Epoch:  2 | Iteration  30/374 | Batch Loss = 0.169319
# Epoch:  2 | Iteration  31/374 | Batch Loss = 0.216086
# Epoch:  2 | Iteration  32/374 | Batch Loss = 0.143019
# Epoch:  2 | Iteration  33/374 | Batch Loss = 0.224281
# Epoch:  2 | Iteration  34/374 | Batch Loss = 0.262880
# Epoch:  2 | Iteration  35/374 | Batch Loss = 0.096825
# Epoch:  2 | Iteration  36/374 | Batch Loss = 0.242029
# Epoch:  2 | Iteration  37/374 | Batch Loss = 0.200245
# Epoch:  2 | Iteration  38/374 | Batch Loss = 0.229746
# Epoch:  2 | Iteration  39/374 | Batch Loss = 0.201638
# Epoch:  2 | Iteration  40/374 | Batch Loss = 0.160395
# Epoch:  2 | Iteration  41/374 | Batch Loss = 0.167231
# Epoch:  2 | Iteration  42/374 | Batch Loss = 0.174566
# Epoch:  2 | Iteration  43/374 | Batch Loss = 0.155955
# Epoch:  2 | Iteration  44/374 | Batch Loss = 0.488754
# Epoch:  2 | Iteration  45/374 | Batch Loss = 0.219236
# Epoch:  2 | Iteration  46/374 | Batch Loss = 0.148084
# Epoch:  2 | Iteration  47/374 | Batch Loss = 0.209592
# Epoch:  2 | Iteration  48/374 | Batch Loss = 0.162554
# Epoch:  2 | Iteration  49/374 | Batch Loss = 0.105243
# Epoch:  2 | Iteration  50/374 | Batch Loss = 0.248788
# Epoch:  2 | Iteration  51/374 | Batch Loss = 0.198720
# Epoch:  2 | Iteration  52/374 | Batch Loss = 0.167112
# Epoch:  2 | Iteration  53/374 | Batch Loss = 0.162453
# Epoch:  2 | Iteration  54/374 | Batch Loss = 0.264492
# Epoch:  2 | Iteration  55/374 | Batch Loss = 0.198930
# Epoch:  2 | Iteration  56/374 | Batch Loss = 0.143258
# Epoch:  2 | Iteration  57/374 | Batch Loss = 0.325378
# Epoch:  2 | Iteration  58/374 | Batch Loss = 0.176488
# Epoch:  2 | Iteration  59/374 | Batch Loss = 0.234820
# Epoch:  2 | Iteration  60/374 | Batch Loss = 0.176364
# Epoch:  2 | Iteration  61/374 | Batch Loss = 0.191550
# Epoch:  2 | Iteration  62/374 | Batch Loss = 0.326478
# Epoch:  2 | Iteration  63/374 | Batch Loss = 0.155122
# Epoch:  2 | Iteration  64/374 | Batch Loss = 0.271678
# Epoch:  2 | Iteration  65/374 | Batch Loss = 0.215767
# Epoch:  2 | Iteration  66/374 | Batch Loss = 0.177375
# Epoch:  2 | Iteration  67/374 | Batch Loss = 0.287058
# Epoch:  2 | Iteration  68/374 | Batch Loss = 0.275615
# Epoch:  2 | Iteration  69/374 | Batch Loss = 0.196628
# Epoch:  2 | Iteration  70/374 | Batch Loss = 0.178496
# Epoch:  2 | Iteration  71/374 | Batch Loss = 0.238989
# Epoch:  2 | Iteration  72/374 | Batch Loss = 0.162172
# Epoch:  2 | Iteration  73/374 | Batch Loss = 0.237139
# Epoch:  2 | Iteration  74/374 | Batch Loss = 0.175960
# Epoch:  2 | Iteration  75/374 | Batch Loss = 0.239980
# Epoch:  2 | Iteration  76/374 | Batch Loss = 0.259637
# Epoch:  2 | Iteration  77/374 | Batch Loss = 0.225219
# Epoch:  2 | Iteration  78/374 | Batch Loss = 0.139472
# Epoch:  2 | Iteration  79/374 | Batch Loss = 0.222579
# Epoch:  2 | Iteration  80/374 | Batch Loss = 0.323934
# Epoch:  2 | Iteration  81/374 | Batch Loss = 0.122961
# Epoch:  2 | Iteration  82/374 | Batch Loss = 0.263971
# Epoch:  2 | Iteration  83/374 | Batch Loss = 0.189851
# Epoch:  2 | Iteration  84/374 | Batch Loss = 0.271901
# Epoch:  2 | Iteration  85/374 | Batch Loss = 0.133029
# Epoch:  2 | Iteration  86/374 | Batch Loss = 0.234323
# Epoch:  2 | Iteration  87/374 | Batch Loss = 0.236900
# Epoch:  2 | Iteration  88/374 | Batch Loss = 0.251055
# Epoch:  2 | Iteration  89/374 | Batch Loss = 0.232408
# Epoch:  2 | Iteration  90/374 | Batch Loss = 0.185746
# Epoch:  2 | Iteration  91/374 | Batch Loss = 0.249084
# Epoch:  2 | Iteration  92/374 | Batch Loss = 0.180243
# Epoch:  2 | Iteration  93/374 | Batch Loss = 0.211880
# Epoch:  2 | Iteration  94/374 | Batch Loss = 0.252601
# Epoch:  2 | Iteration  95/374 | Batch Loss = 0.187768
# Epoch:  2 | Iteration  96/374 | Batch Loss = 0.191280
# Epoch:  2 | Iteration  97/374 | Batch Loss = 0.210366
# Epoch:  2 | Iteration  98/374 | Batch Loss = 0.138575
# Epoch:  2 | Iteration  99/374 | Batch Loss = 0.243671
# Epoch:  2 | Iteration 100/374 | Batch Loss = 0.228467
# Epoch:  2 | Iteration 101/374 | Batch Loss = 0.175104
# Epoch:  2 | Iteration 102/374 | Batch Loss = 0.263614
# Epoch:  2 | Iteration 103/374 | Batch Loss = 0.155610
# Epoch:  2 | Iteration 104/374 | Batch Loss = 0.111629
# Epoch:  2 | Iteration 105/374 | Batch Loss = 0.274456
# Epoch:  2 | Iteration 106/374 | Batch Loss = 0.107290
# Epoch:  2 | Iteration 107/374 | Batch Loss = 0.214876
# Epoch:  2 | Iteration 108/374 | Batch Loss = 0.117305
# Epoch:  2 | Iteration 109/374 | Batch Loss = 0.270541
# Epoch:  2 | Iteration 110/374 | Batch Loss = 0.216448
# Epoch:  2 | Iteration 111/374 | Batch Loss = 0.193474
# Epoch:  2 | Iteration 112/374 | Batch Loss = 0.128696
# Epoch:  2 | Iteration 113/374 | Batch Loss = 0.316931
# Epoch:  2 | Iteration 114/374 | Batch Loss = 0.171789
# Epoch:  2 | Iteration 115/374 | Batch Loss = 0.101273
# Epoch:  2 | Iteration 116/374 | Batch Loss = 0.182327
# Epoch:  2 | Iteration 117/374 | Batch Loss = 0.271555
# Epoch:  2 | Iteration 118/374 | Batch Loss = 0.106091
# Epoch:  2 | Iteration 119/374 | Batch Loss = 0.128031
# Epoch:  2 | Iteration 120/374 | Batch Loss = 0.123661
# Epoch:  2 | Iteration 121/374 | Batch Loss = 0.237072
# Epoch:  2 | Iteration 122/374 | Batch Loss = 0.138175
# Epoch:  2 | Iteration 123/374 | Batch Loss = 0.115511
# Epoch:  2 | Iteration 124/374 | Batch Loss = 0.289959
# Epoch:  2 | Iteration 125/374 | Batch Loss = 0.190093
# Epoch:  2 | Iteration 126/374 | Batch Loss = 0.163213
# Epoch:  2 | Iteration 127/374 | Batch Loss = 0.295455
# Epoch:  2 | Iteration 128/374 | Batch Loss = 0.144853
# Epoch:  2 | Iteration 129/374 | Batch Loss = 0.145816
# Epoch:  2 | Iteration 130/374 | Batch Loss = 0.189608
# Epoch:  2 | Iteration 131/374 | Batch Loss = 0.215609
# Epoch:  2 | Iteration 132/374 | Batch Loss = 0.156690
# Epoch:  2 | Iteration 133/374 | Batch Loss = 0.282975
# Epoch:  2 | Iteration 134/374 | Batch Loss = 0.161278
# Epoch:  2 | Iteration 135/374 | Batch Loss = 0.264366
# Epoch:  2 | Iteration 136/374 | Batch Loss = 0.265901
# Epoch:  2 | Iteration 137/374 | Batch Loss = 0.137394
# Epoch:  2 | Iteration 138/374 | Batch Loss = 0.255817
# Epoch:  2 | Iteration 139/374 | Batch Loss = 0.145222
# Epoch:  2 | Iteration 140/374 | Batch Loss = 0.234720
# Epoch:  2 | Iteration 141/374 | Batch Loss = 0.119162
# Epoch:  2 | Iteration 142/374 | Batch Loss = 0.256670
# Epoch:  2 | Iteration 143/374 | Batch Loss = 0.214964
# Epoch:  2 | Iteration 144/374 | Batch Loss = 0.145813
# Epoch:  2 | Iteration 145/374 | Batch Loss = 0.318195
# Epoch:  2 | Iteration 146/374 | Batch Loss = 0.138932
# Epoch:  2 | Iteration 147/374 | Batch Loss = 0.147146
# Epoch:  2 | Iteration 148/374 | Batch Loss = 0.209162
# Epoch:  2 | Iteration 149/374 | Batch Loss = 0.240175
# Epoch:  2 | Iteration 150/374 | Batch Loss = 0.166362
# Epoch:  2 | Iteration 151/374 | Batch Loss = 0.112107
# Epoch:  2 | Iteration 152/374 | Batch Loss = 0.136326
# Epoch:  2 | Iteration 153/374 | Batch Loss = 0.166726
# Epoch:  2 | Iteration 154/374 | Batch Loss = 0.229196
# Epoch:  2 | Iteration 155/374 | Batch Loss = 0.225376
# Epoch:  2 | Iteration 156/374 | Batch Loss = 0.154395
# Epoch:  2 | Iteration 157/374 | Batch Loss = 0.237878
# Epoch:  2 | Iteration 158/374 | Batch Loss = 0.149552
# Epoch:  2 | Iteration 159/374 | Batch Loss = 0.248708
# Epoch:  2 | Iteration 160/374 | Batch Loss = 0.237019
# Epoch:  2 | Iteration 161/374 | Batch Loss = 0.120215
# Epoch:  2 | Iteration 162/374 | Batch Loss = 0.193169
# Epoch:  2 | Iteration 163/374 | Batch Loss = 0.181507
# Epoch:  2 | Iteration 164/374 | Batch Loss = 0.309939
# Epoch:  2 | Iteration 165/374 | Batch Loss = 0.259559
# Epoch:  2 | Iteration 166/374 | Batch Loss = 0.254071
# Epoch:  2 | Iteration 167/374 | Batch Loss = 0.213176
# Epoch:  2 | Iteration 168/374 | Batch Loss = 0.258120
# Epoch:  2 | Iteration 169/374 | Batch Loss = 0.100627
# Epoch:  2 | Iteration 170/374 | Batch Loss = 0.245571
# Epoch:  2 | Iteration 171/374 | Batch Loss = 0.168830
# Epoch:  2 | Iteration 172/374 | Batch Loss = 0.257543
# Epoch:  2 | Iteration 173/374 | Batch Loss = 0.160463
# Epoch:  2 | Iteration 174/374 | Batch Loss = 0.214809
# Epoch:  2 | Iteration 175/374 | Batch Loss = 0.175902
# Epoch:  2 | Iteration 176/374 | Batch Loss = 0.162076
# Epoch:  2 | Iteration 177/374 | Batch Loss = 0.246451
# Epoch:  2 | Iteration 178/374 | Batch Loss = 0.189359
# Epoch:  2 | Iteration 179/374 | Batch Loss = 0.108203
# Epoch:  2 | Iteration 180/374 | Batch Loss = 0.237178
# Epoch:  2 | Iteration 181/374 | Batch Loss = 0.290454
# Epoch:  2 | Iteration 182/374 | Batch Loss = 0.156329
# Epoch:  2 | Iteration 183/374 | Batch Loss = 0.204987
# Epoch:  2 | Iteration 184/374 | Batch Loss = 0.276893
# Epoch:  2 | Iteration 185/374 | Batch Loss = 0.247607
# Epoch:  2 | Iteration 186/374 | Batch Loss = 0.200116
# Epoch:  2 | Iteration 187/374 | Batch Loss = 0.095392
# Epoch:  2 | Iteration 188/374 | Batch Loss = 0.235676
# Epoch:  2 | Iteration 189/374 | Batch Loss = 0.363811
# Epoch:  2 | Iteration 190/374 | Batch Loss = 0.139242
# Epoch:  2 | Iteration 191/374 | Batch Loss = 0.166200
# Epoch:  2 | Iteration 192/374 | Batch Loss = 0.185552
# Epoch:  2 | Iteration 193/374 | Batch Loss = 0.271344
# Epoch:  2 | Iteration 194/374 | Batch Loss = 0.389918
# Epoch:  2 | Iteration 195/374 | Batch Loss = 0.147602
# Epoch:  2 | Iteration 196/374 | Batch Loss = 0.167248
# Epoch:  2 | Iteration 197/374 | Batch Loss = 0.152309
# Epoch:  2 | Iteration 198/374 | Batch Loss = 0.138626
# Epoch:  2 | Iteration 199/374 | Batch Loss = 0.222610
# Epoch:  2 | Iteration 200/374 | Batch Loss = 0.109113
# Epoch:  2 | Iteration 201/374 | Batch Loss = 0.202254
# Epoch:  2 | Iteration 202/374 | Batch Loss = 0.193024
# Epoch:  2 | Iteration 203/374 | Batch Loss = 0.282201
# Epoch:  2 | Iteration 204/374 | Batch Loss = 0.186155
# Epoch:  2 | Iteration 205/374 | Batch Loss = 0.152671
# Epoch:  2 | Iteration 206/374 | Batch Loss = 0.159721
# Epoch:  2 | Iteration 207/374 | Batch Loss = 0.183629
# Epoch:  2 | Iteration 208/374 | Batch Loss = 0.187428
# Epoch:  2 | Iteration 209/374 | Batch Loss = 0.193841
# Epoch:  2 | Iteration 210/374 | Batch Loss = 0.250157
# Epoch:  2 | Iteration 211/374 | Batch Loss = 0.147592
# Epoch:  2 | Iteration 212/374 | Batch Loss = 0.252609
# Epoch:  2 | Iteration 213/374 | Batch Loss = 0.193281
# Epoch:  2 | Iteration 214/374 | Batch Loss = 0.313248
# Epoch:  2 | Iteration 215/374 | Batch Loss = 0.308198
# Epoch:  2 | Iteration 216/374 | Batch Loss = 0.254975
# Epoch:  2 | Iteration 217/374 | Batch Loss = 0.159127
# Epoch:  2 | Iteration 218/374 | Batch Loss = 0.200613
# Epoch:  2 | Iteration 219/374 | Batch Loss = 0.284754
# Epoch:  2 | Iteration 220/374 | Batch Loss = 0.169023
# Epoch:  2 | Iteration 221/374 | Batch Loss = 0.215379
# Epoch:  2 | Iteration 222/374 | Batch Loss = 0.223278
# Epoch:  2 | Iteration 223/374 | Batch Loss = 0.283926
# Epoch:  2 | Iteration 224/374 | Batch Loss = 0.236911
# Epoch:  2 | Iteration 225/374 | Batch Loss = 0.154976
# Epoch:  2 | Iteration 226/374 | Batch Loss = 0.278563
# Epoch:  2 | Iteration 227/374 | Batch Loss = 0.266151
# Epoch:  2 | Iteration 228/374 | Batch Loss = 0.141181
# Epoch:  2 | Iteration 229/374 | Batch Loss = 0.247664
# Epoch:  2 | Iteration 230/374 | Batch Loss = 0.186691
# Epoch:  2 | Iteration 231/374 | Batch Loss = 0.203767
# Epoch:  2 | Iteration 232/374 | Batch Loss = 0.137677
# Epoch:  2 | Iteration 233/374 | Batch Loss = 0.194995
# Epoch:  2 | Iteration 234/374 | Batch Loss = 0.119815
# Epoch:  2 | Iteration 235/374 | Batch Loss = 0.156668
# Epoch:  2 | Iteration 236/374 | Batch Loss = 0.155344
# Epoch:  2 | Iteration 237/374 | Batch Loss = 0.151249
# Epoch:  2 | Iteration 238/374 | Batch Loss = 0.419381
# Epoch:  2 | Iteration 239/374 | Batch Loss = 0.124107
# Epoch:  2 | Iteration 240/374 | Batch Loss = 0.222345
# Epoch:  2 | Iteration 241/374 | Batch Loss = 0.217468
# Epoch:  2 | Iteration 242/374 | Batch Loss = 0.173032
# Epoch:  2 | Iteration 243/374 | Batch Loss = 0.212760
# Epoch:  2 | Iteration 244/374 | Batch Loss = 0.143863
# Epoch:  2 | Iteration 245/374 | Batch Loss = 0.324805
# Epoch:  2 | Iteration 246/374 | Batch Loss = 0.276268
# Epoch:  2 | Iteration 247/374 | Batch Loss = 0.333779
# Epoch:  2 | Iteration 248/374 | Batch Loss = 0.127916
# Epoch:  2 | Iteration 249/374 | Batch Loss = 0.166858
# Epoch:  2 | Iteration 250/374 | Batch Loss = 0.196326
# Epoch:  2 | Iteration 251/374 | Batch Loss = 0.169466
# Epoch:  2 | Iteration 252/374 | Batch Loss = 0.204120
# Epoch:  2 | Iteration 253/374 | Batch Loss = 0.364686
# Epoch:  2 | Iteration 254/374 | Batch Loss = 0.248940
# Epoch:  2 | Iteration 255/374 | Batch Loss = 0.219180
# Epoch:  2 | Iteration 256/374 | Batch Loss = 0.350739
# Epoch:  2 | Iteration 257/374 | Batch Loss = 0.262571
# Epoch:  2 | Iteration 258/374 | Batch Loss = 0.229159
# Epoch:  2 | Iteration 259/374 | Batch Loss = 0.193756
# Epoch:  2 | Iteration 260/374 | Batch Loss = 0.177808
# Epoch:  2 | Iteration 261/374 | Batch Loss = 0.168123
# Epoch:  2 | Iteration 262/374 | Batch Loss = 0.206668
# Epoch:  2 | Iteration 263/374 | Batch Loss = 0.227702
# Epoch:  2 | Iteration 264/374 | Batch Loss = 0.199351
# Epoch:  2 | Iteration 265/374 | Batch Loss = 0.304933
# Epoch:  2 | Iteration 266/374 | Batch Loss = 0.282164
# Epoch:  2 | Iteration 267/374 | Batch Loss = 0.246308
# Epoch:  2 | Iteration 268/374 | Batch Loss = 0.184314
# Epoch:  2 | Iteration 269/374 | Batch Loss = 0.139024
# Epoch:  2 | Iteration 270/374 | Batch Loss = 0.185331
# Epoch:  2 | Iteration 271/374 | Batch Loss = 0.214842
# Epoch:  2 | Iteration 272/374 | Batch Loss = 0.136683
# Epoch:  2 | Iteration 273/374 | Batch Loss = 0.170544
# Epoch:  2 | Iteration 274/374 | Batch Loss = 0.135154
# Epoch:  2 | Iteration 275/374 | Batch Loss = 0.201250
# Epoch:  2 | Iteration 276/374 | Batch Loss = 0.279132
# Epoch:  2 | Iteration 277/374 | Batch Loss = 0.218191
# Epoch:  2 | Iteration 278/374 | Batch Loss = 0.205209
# Epoch:  2 | Iteration 279/374 | Batch Loss = 0.380378
# Epoch:  2 | Iteration 280/374 | Batch Loss = 0.222034
# Epoch:  2 | Iteration 281/374 | Batch Loss = 0.222400
# Epoch:  2 | Iteration 282/374 | Batch Loss = 0.244094
# Epoch:  2 | Iteration 283/374 | Batch Loss = 0.269930
# Epoch:  2 | Iteration 284/374 | Batch Loss = 0.309469
# Epoch:  2 | Iteration 285/374 | Batch Loss = 0.130207
# Epoch:  2 | Iteration 286/374 | Batch Loss = 0.117456
# Epoch:  2 | Iteration 287/374 | Batch Loss = 0.133088
# Epoch:  2 | Iteration 288/374 | Batch Loss = 0.276259
# Epoch:  2 | Iteration 289/374 | Batch Loss = 0.131115
# Epoch:  2 | Iteration 290/374 | Batch Loss = 0.211964
# Epoch:  2 | Iteration 291/374 | Batch Loss = 0.293480
# Epoch:  2 | Iteration 292/374 | Batch Loss = 0.220994
# Epoch:  2 | Iteration 293/374 | Batch Loss = 0.201775
# Epoch:  2 | Iteration 294/374 | Batch Loss = 0.190634
# Epoch:  2 | Iteration 295/374 | Batch Loss = 0.259380
# Epoch:  2 | Iteration 296/374 | Batch Loss = 0.199133
# Epoch:  2 | Iteration 297/374 | Batch Loss = 0.119220
# Epoch:  2 | Iteration 298/374 | Batch Loss = 0.164670
# Epoch:  2 | Iteration 299/374 | Batch Loss = 0.148382
# Epoch:  2 | Iteration 300/374 | Batch Loss = 0.160593
# Epoch:  2 | Iteration 301/374 | Batch Loss = 0.203579
# Epoch:  2 | Iteration 302/374 | Batch Loss = 0.206417
# Epoch:  2 | Iteration 303/374 | Batch Loss = 0.203147
# Epoch:  2 | Iteration 304/374 | Batch Loss = 0.144416
# Epoch:  2 | Iteration 305/374 | Batch Loss = 0.195043
# Epoch:  2 | Iteration 306/374 | Batch Loss = 0.266201
# Epoch:  2 | Iteration 307/374 | Batch Loss = 0.149781
# Epoch:  2 | Iteration 308/374 | Batch Loss = 0.235324
# Epoch:  2 | Iteration 309/374 | Batch Loss = 0.254571
# Epoch:  2 | Iteration 310/374 | Batch Loss = 0.111818
# Epoch:  2 | Iteration 311/374 | Batch Loss = 0.267352
# Epoch:  2 | Iteration 312/374 | Batch Loss = 0.202526
# Epoch:  2 | Iteration 313/374 | Batch Loss = 0.226931
# Epoch:  2 | Iteration 314/374 | Batch Loss = 0.112342
# Epoch:  2 | Iteration 315/374 | Batch Loss = 0.179427
# Epoch:  2 | Iteration 316/374 | Batch Loss = 0.260157
# Epoch:  2 | Iteration 317/374 | Batch Loss = 0.126830
# Epoch:  2 | Iteration 318/374 | Batch Loss = 0.150980
# Epoch:  2 | Iteration 319/374 | Batch Loss = 0.241906
# Epoch:  2 | Iteration 320/374 | Batch Loss = 0.167409
# Epoch:  2 | Iteration 321/374 | Batch Loss = 0.291109
# Epoch:  2 | Iteration 322/374 | Batch Loss = 0.156165
# Epoch:  2 | Iteration 323/374 | Batch Loss = 0.301164
# Epoch:  2 | Iteration 324/374 | Batch Loss = 0.178309
# Epoch:  2 | Iteration 325/374 | Batch Loss = 0.204792
# Epoch:  2 | Iteration 326/374 | Batch Loss = 0.172860
# Epoch:  2 | Iteration 327/374 | Batch Loss = 0.282368
# Epoch:  2 | Iteration 328/374 | Batch Loss = 0.171790
# Epoch:  2 | Iteration 329/374 | Batch Loss = 0.356156
# Epoch:  2 | Iteration 330/374 | Batch Loss = 0.196866
# Epoch:  2 | Iteration 331/374 | Batch Loss = 0.321023
# Epoch:  2 | Iteration 332/374 | Batch Loss = 0.125420
# Epoch:  2 | Iteration 333/374 | Batch Loss = 0.150252
# Epoch:  2 | Iteration 334/374 | Batch Loss = 0.309252
# Epoch:  2 | Iteration 335/374 | Batch Loss = 0.234430
# Epoch:  2 | Iteration 336/374 | Batch Loss = 0.320714
# Epoch:  2 | Iteration 337/374 | Batch Loss = 0.204999
# Epoch:  2 | Iteration 338/374 | Batch Loss = 0.154068
# Epoch:  2 | Iteration 339/374 | Batch Loss = 0.275139
# Epoch:  2 | Iteration 340/374 | Batch Loss = 0.201815
# Epoch:  2 | Iteration 341/374 | Batch Loss = 0.299574
# Epoch:  2 | Iteration 342/374 | Batch Loss = 0.141957
# Epoch:  2 | Iteration 343/374 | Batch Loss = 0.146820
# Epoch:  2 | Iteration 344/374 | Batch Loss = 0.106047
# Epoch:  2 | Iteration 345/374 | Batch Loss = 0.133241
# Epoch:  2 | Iteration 346/374 | Batch Loss = 0.162803
# Epoch:  2 | Iteration 347/374 | Batch Loss = 0.359461
# Epoch:  2 | Iteration 348/374 | Batch Loss = 0.248170
# Epoch:  2 | Iteration 349/374 | Batch Loss = 0.240582
# Epoch:  2 | Iteration 350/374 | Batch Loss = 0.143589
# Epoch:  2 | Iteration 351/374 | Batch Loss = 0.149636
# Epoch:  2 | Iteration 352/374 | Batch Loss = 0.254254
# Epoch:  2 | Iteration 353/374 | Batch Loss = 0.163154
# Epoch:  2 | Iteration 354/374 | Batch Loss = 0.282556
# Epoch:  2 | Iteration 355/374 | Batch Loss = 0.227908
# Epoch:  2 | Iteration 356/374 | Batch Loss = 0.220250
# Epoch:  2 | Iteration 357/374 | Batch Loss = 0.220539
# Epoch:  2 | Iteration 358/374 | Batch Loss = 0.146180
# Epoch:  2 | Iteration 359/374 | Batch Loss = 0.275494
# Epoch:  2 | Iteration 360/374 | Batch Loss = 0.187701
# Epoch:  2 | Iteration 361/374 | Batch Loss = 0.213115
# Epoch:  2 | Iteration 362/374 | Batch Loss = 0.171235
# Epoch:  2 | Iteration 363/374 | Batch Loss = 0.251033
# Epoch:  2 | Iteration 364/374 | Batch Loss = 0.222031
# Epoch:  2 | Iteration 365/374 | Batch Loss = 0.142420
# Epoch:  2 | Iteration 366/374 | Batch Loss = 0.162673
# Epoch:  2 | Iteration 367/374 | Batch Loss = 0.222321
# Epoch:  2 | Iteration 368/374 | Batch Loss = 0.161123
# Epoch:  2 | Iteration 369/374 | Batch Loss = 0.274169
# Epoch:  2 | Iteration 370/374 | Batch Loss = 0.223160
# Epoch:  2 | Iteration 371/374 | Batch Loss = 0.151233
# Epoch:  2 | Iteration 372/374 | Batch Loss = 0.186407
# Epoch:  2 | Iteration 373/374 | Batch Loss = 0.191453
# Epoch:  3 | Iteration   0/374 | Batch Loss = 0.154557
# Epoch:  3 | Iteration   1/374 | Batch Loss = 0.076919
# Epoch:  3 | Iteration   2/374 | Batch Loss = 0.147485
# Epoch:  3 | Iteration   3/374 | Batch Loss = 0.175377
# Epoch:  3 | Iteration   4/374 | Batch Loss = 0.170601
# Epoch:  3 | Iteration   5/374 | Batch Loss = 0.165511
# Epoch:  3 | Iteration   6/374 | Batch Loss = 0.110756
# Epoch:  3 | Iteration   7/374 | Batch Loss = 0.136731
# Epoch:  3 | Iteration   8/374 | Batch Loss = 0.277728
# Epoch:  3 | Iteration   9/374 | Batch Loss = 0.174985
# Epoch:  3 | Iteration  10/374 | Batch Loss = 0.106045
# Epoch:  3 | Iteration  11/374 | Batch Loss = 0.165014
# Epoch:  3 | Iteration  12/374 | Batch Loss = 0.144145
# Epoch:  3 | Iteration  13/374 | Batch Loss = 0.262082
# Epoch:  3 | Iteration  14/374 | Batch Loss = 0.102549
# Epoch:  3 | Iteration  15/374 | Batch Loss = 0.232110
# Epoch:  3 | Iteration  16/374 | Batch Loss = 0.242166
# Epoch:  3 | Iteration  17/374 | Batch Loss = 0.205726
# Epoch:  3 | Iteration  18/374 | Batch Loss = 0.278186
# Epoch:  3 | Iteration  19/374 | Batch Loss = 0.197032
# Epoch:  3 | Iteration  20/374 | Batch Loss = 0.092765
# Epoch:  3 | Iteration  21/374 | Batch Loss = 0.132110
# Epoch:  3 | Iteration  22/374 | Batch Loss = 0.133970
# Epoch:  3 | Iteration  23/374 | Batch Loss = 0.084394
# Epoch:  3 | Iteration  24/374 | Batch Loss = 0.202194
# Epoch:  3 | Iteration  25/374 | Batch Loss = 0.090485
# Epoch:  3 | Iteration  26/374 | Batch Loss = 0.153605
# Epoch:  3 | Iteration  27/374 | Batch Loss = 0.169281
# Epoch:  3 | Iteration  28/374 | Batch Loss = 0.310884
# Epoch:  3 | Iteration  29/374 | Batch Loss = 0.224667
# Epoch:  3 | Iteration  30/374 | Batch Loss = 0.109549
# Epoch:  3 | Iteration  31/374 | Batch Loss = 0.124231
# Epoch:  3 | Iteration  32/374 | Batch Loss = 0.248900
# Epoch:  3 | Iteration  33/374 | Batch Loss = 0.211161
# Epoch:  3 | Iteration  34/374 | Batch Loss = 0.094191
# Epoch:  3 | Iteration  35/374 | Batch Loss = 0.166917
# Epoch:  3 | Iteration  36/374 | Batch Loss = 0.162487
# Epoch:  3 | Iteration  37/374 | Batch Loss = 0.162406
# Epoch:  3 | Iteration  38/374 | Batch Loss = 0.159658
# Epoch:  3 | Iteration  39/374 | Batch Loss = 0.171597
# Epoch:  3 | Iteration  40/374 | Batch Loss = 0.153748
# Epoch:  3 | Iteration  41/374 | Batch Loss = 0.230727
# Epoch:  3 | Iteration  42/374 | Batch Loss = 0.137215
# Epoch:  3 | Iteration  43/374 | Batch Loss = 0.150375
# Epoch:  3 | Iteration  44/374 | Batch Loss = 0.212194
# Epoch:  3 | Iteration  45/374 | Batch Loss = 0.286273
# Epoch:  3 | Iteration  46/374 | Batch Loss = 0.078456
# Epoch:  3 | Iteration  47/374 | Batch Loss = 0.164547
# Epoch:  3 | Iteration  48/374 | Batch Loss = 0.137939
# Epoch:  3 | Iteration  49/374 | Batch Loss = 0.307052
# Epoch:  3 | Iteration  50/374 | Batch Loss = 0.127426
# Epoch:  3 | Iteration  51/374 | Batch Loss = 0.140275
# Epoch:  3 | Iteration  52/374 | Batch Loss = 0.224708
# Epoch:  3 | Iteration  53/374 | Batch Loss = 0.074923
# Epoch:  3 | Iteration  54/374 | Batch Loss = 0.112728
# Epoch:  3 | Iteration  55/374 | Batch Loss = 0.188689
# Epoch:  3 | Iteration  56/374 | Batch Loss = 0.124303
# Epoch:  3 | Iteration  57/374 | Batch Loss = 0.156422
# Epoch:  3 | Iteration  58/374 | Batch Loss = 0.131592
# Epoch:  3 | Iteration  59/374 | Batch Loss = 0.068646
# Epoch:  3 | Iteration  60/374 | Batch Loss = 0.079111
# Epoch:  3 | Iteration  61/374 | Batch Loss = 0.174752
# Epoch:  3 | Iteration  62/374 | Batch Loss = 0.143433
# Epoch:  3 | Iteration  63/374 | Batch Loss = 0.127221
# Epoch:  3 | Iteration  64/374 | Batch Loss = 0.211307
# Epoch:  3 | Iteration  65/374 | Batch Loss = 0.173653
# Epoch:  3 | Iteration  66/374 | Batch Loss = 0.123509
# Epoch:  3 | Iteration  67/374 | Batch Loss = 0.086593
# Epoch:  3 | Iteration  68/374 | Batch Loss = 0.101387
# Epoch:  3 | Iteration  69/374 | Batch Loss = 0.204298
# Epoch:  3 | Iteration  70/374 | Batch Loss = 0.240502
# Epoch:  3 | Iteration  71/374 | Batch Loss = 0.190606
# Epoch:  3 | Iteration  72/374 | Batch Loss = 0.078104
# Epoch:  3 | Iteration  73/374 | Batch Loss = 0.076340
# Epoch:  3 | Iteration  74/374 | Batch Loss = 0.111183
# Epoch:  3 | Iteration  75/374 | Batch Loss = 0.131439
# Epoch:  3 | Iteration  76/374 | Batch Loss = 0.125194
# Epoch:  3 | Iteration  77/374 | Batch Loss = 0.220398
# Epoch:  3 | Iteration  78/374 | Batch Loss = 0.162481
# Epoch:  3 | Iteration  79/374 | Batch Loss = 0.137796
# Epoch:  3 | Iteration  80/374 | Batch Loss = 0.086343
# Epoch:  3 | Iteration  81/374 | Batch Loss = 0.197509
# Epoch:  3 | Iteration  82/374 | Batch Loss = 0.234335
# Epoch:  3 | Iteration  83/374 | Batch Loss = 0.148435
# Epoch:  3 | Iteration  84/374 | Batch Loss = 0.227868
# Epoch:  3 | Iteration  85/374 | Batch Loss = 0.130913
# Epoch:  3 | Iteration  86/374 | Batch Loss = 0.161496
# Epoch:  3 | Iteration  87/374 | Batch Loss = 0.140826
# Epoch:  3 | Iteration  88/374 | Batch Loss = 0.197963
# Epoch:  3 | Iteration  89/374 | Batch Loss = 0.119394
# Epoch:  3 | Iteration  90/374 | Batch Loss = 0.206857
# Epoch:  3 | Iteration  91/374 | Batch Loss = 0.144832
# Epoch:  3 | Iteration  92/374 | Batch Loss = 0.211384
# Epoch:  3 | Iteration  93/374 | Batch Loss = 0.220073
# Epoch:  3 | Iteration  94/374 | Batch Loss = 0.126612
# Epoch:  3 | Iteration  95/374 | Batch Loss = 0.220700
# Epoch:  3 | Iteration  96/374 | Batch Loss = 0.141287
# Epoch:  3 | Iteration  97/374 | Batch Loss = 0.192016
# Epoch:  3 | Iteration  98/374 | Batch Loss = 0.204453
# Epoch:  3 | Iteration  99/374 | Batch Loss = 0.096618
# Epoch:  3 | Iteration 100/374 | Batch Loss = 0.174132
# Epoch:  3 | Iteration 101/374 | Batch Loss = 0.174127
# Epoch:  3 | Iteration 102/374 | Batch Loss = 0.152403
# Epoch:  3 | Iteration 103/374 | Batch Loss = 0.118213
# Epoch:  3 | Iteration 104/374 | Batch Loss = 0.184277
# Epoch:  3 | Iteration 105/374 | Batch Loss = 0.223100
# Epoch:  3 | Iteration 106/374 | Batch Loss = 0.144936
# Epoch:  3 | Iteration 107/374 | Batch Loss = 0.066330
# Epoch:  3 | Iteration 108/374 | Batch Loss = 0.187818
# Epoch:  3 | Iteration 109/374 | Batch Loss = 0.183556
# Epoch:  3 | Iteration 110/374 | Batch Loss = 0.223978
# Epoch:  3 | Iteration 111/374 | Batch Loss = 0.219859
# Epoch:  3 | Iteration 112/374 | Batch Loss = 0.182148
# Epoch:  3 | Iteration 113/374 | Batch Loss = 0.118422
# Epoch:  3 | Iteration 114/374 | Batch Loss = 0.142181
# Epoch:  3 | Iteration 115/374 | Batch Loss = 0.086869
# Epoch:  3 | Iteration 116/374 | Batch Loss = 0.218203
# Epoch:  3 | Iteration 117/374 | Batch Loss = 0.382603
# Epoch:  3 | Iteration 118/374 | Batch Loss = 0.150241
# Epoch:  3 | Iteration 119/374 | Batch Loss = 0.144763
# Epoch:  3 | Iteration 120/374 | Batch Loss = 0.168151
# Epoch:  3 | Iteration 121/374 | Batch Loss = 0.081482
# Epoch:  3 | Iteration 122/374 | Batch Loss = 0.151319
# Epoch:  3 | Iteration 123/374 | Batch Loss = 0.149697
# Epoch:  3 | Iteration 124/374 | Batch Loss = 0.201886
# Epoch:  3 | Iteration 125/374 | Batch Loss = 0.178433
# Epoch:  3 | Iteration 126/374 | Batch Loss = 0.053470
# Epoch:  3 | Iteration 127/374 | Batch Loss = 0.098847
# Epoch:  3 | Iteration 128/374 | Batch Loss = 0.182857
# Epoch:  3 | Iteration 129/374 | Batch Loss = 0.228660
# Epoch:  3 | Iteration 130/374 | Batch Loss = 0.213604
# Epoch:  3 | Iteration 131/374 | Batch Loss = 0.144924
# Epoch:  3 | Iteration 132/374 | Batch Loss = 0.276491
# Epoch:  3 | Iteration 133/374 | Batch Loss = 0.257908
# Epoch:  3 | Iteration 134/374 | Batch Loss = 0.137600
# Epoch:  3 | Iteration 135/374 | Batch Loss = 0.153630
# Epoch:  3 | Iteration 136/374 | Batch Loss = 0.144065
# Epoch:  3 | Iteration 137/374 | Batch Loss = 0.226547
# Epoch:  3 | Iteration 138/374 | Batch Loss = 0.080047
# Epoch:  3 | Iteration 139/374 | Batch Loss = 0.286026
# Epoch:  3 | Iteration 140/374 | Batch Loss = 0.220712
# Epoch:  3 | Iteration 141/374 | Batch Loss = 0.095102
# Epoch:  3 | Iteration 142/374 | Batch Loss = 0.241342
# Epoch:  3 | Iteration 143/374 | Batch Loss = 0.239984
# Epoch:  3 | Iteration 144/374 | Batch Loss = 0.184122
# Epoch:  3 | Iteration 145/374 | Batch Loss = 0.191817
# Epoch:  3 | Iteration 146/374 | Batch Loss = 0.207918
# Epoch:  3 | Iteration 147/374 | Batch Loss = 0.221280
# Epoch:  3 | Iteration 148/374 | Batch Loss = 0.129364
# Epoch:  3 | Iteration 149/374 | Batch Loss = 0.149910
# Epoch:  3 | Iteration 150/374 | Batch Loss = 0.170082
# Epoch:  3 | Iteration 151/374 | Batch Loss = 0.158193
# Epoch:  3 | Iteration 152/374 | Batch Loss = 0.139373
# Epoch:  3 | Iteration 153/374 | Batch Loss = 0.136522
# Epoch:  3 | Iteration 154/374 | Batch Loss = 0.176343
# Epoch:  3 | Iteration 155/374 | Batch Loss = 0.148185
# Epoch:  3 | Iteration 156/374 | Batch Loss = 0.182276
# Epoch:  3 | Iteration 157/374 | Batch Loss = 0.174885
# Epoch:  3 | Iteration 158/374 | Batch Loss = 0.194554
# Epoch:  3 | Iteration 159/374 | Batch Loss = 0.362615
# Epoch:  3 | Iteration 160/374 | Batch Loss = 0.186060
# Epoch:  3 | Iteration 161/374 | Batch Loss = 0.263975
# Epoch:  3 | Iteration 162/374 | Batch Loss = 0.217753
# Epoch:  3 | Iteration 163/374 | Batch Loss = 0.133318
# Epoch:  3 | Iteration 164/374 | Batch Loss = 0.149574
# Epoch:  3 | Iteration 165/374 | Batch Loss = 0.116410
# Epoch:  3 | Iteration 166/374 | Batch Loss = 0.097938
# Epoch:  3 | Iteration 167/374 | Batch Loss = 0.182787
# Epoch:  3 | Iteration 168/374 | Batch Loss = 0.231134
# Epoch:  3 | Iteration 169/374 | Batch Loss = 0.128978
# Epoch:  3 | Iteration 170/374 | Batch Loss = 0.149015
# Epoch:  3 | Iteration 171/374 | Batch Loss = 0.136393
# Epoch:  3 | Iteration 172/374 | Batch Loss = 0.218253
# Epoch:  3 | Iteration 173/374 | Batch Loss = 0.116273
# Epoch:  3 | Iteration 174/374 | Batch Loss = 0.158190
# Epoch:  3 | Iteration 175/374 | Batch Loss = 0.185695
# Epoch:  3 | Iteration 176/374 | Batch Loss = 0.268391
# Epoch:  3 | Iteration 177/374 | Batch Loss = 0.111066
# Epoch:  3 | Iteration 178/374 | Batch Loss = 0.164768
# Epoch:  3 | Iteration 179/374 | Batch Loss = 0.104622
# Epoch:  3 | Iteration 180/374 | Batch Loss = 0.205591
# Epoch:  3 | Iteration 181/374 | Batch Loss = 0.297249
# Epoch:  3 | Iteration 182/374 | Batch Loss = 0.132169
# Epoch:  3 | Iteration 183/374 | Batch Loss = 0.242155
# Epoch:  3 | Iteration 184/374 | Batch Loss = 0.125679
# Epoch:  3 | Iteration 185/374 | Batch Loss = 0.161750
# Epoch:  3 | Iteration 186/374 | Batch Loss = 0.156783
# Epoch:  3 | Iteration 187/374 | Batch Loss = 0.216734
# Epoch:  3 | Iteration 188/374 | Batch Loss = 0.081154
# Epoch:  3 | Iteration 189/374 | Batch Loss = 0.139445
# Epoch:  3 | Iteration 190/374 | Batch Loss = 0.165162
# Epoch:  3 | Iteration 191/374 | Batch Loss = 0.126111
# Epoch:  3 | Iteration 192/374 | Batch Loss = 0.306445
# Epoch:  3 | Iteration 193/374 | Batch Loss = 0.086902
# Epoch:  3 | Iteration 194/374 | Batch Loss = 0.162009
# Epoch:  3 | Iteration 195/374 | Batch Loss = 0.326923
# Epoch:  3 | Iteration 196/374 | Batch Loss = 0.170008
# Epoch:  3 | Iteration 197/374 | Batch Loss = 0.113739
# Epoch:  3 | Iteration 198/374 | Batch Loss = 0.342577
# Epoch:  3 | Iteration 199/374 | Batch Loss = 0.172679
# Epoch:  3 | Iteration 200/374 | Batch Loss = 0.243814
# Epoch:  3 | Iteration 201/374 | Batch Loss = 0.108434
# Epoch:  3 | Iteration 202/374 | Batch Loss = 0.275695
# Epoch:  3 | Iteration 203/374 | Batch Loss = 0.236187
# Epoch:  3 | Iteration 204/374 | Batch Loss = 0.147762
# Epoch:  3 | Iteration 205/374 | Batch Loss = 0.172143
# Epoch:  3 | Iteration 206/374 | Batch Loss = 0.214002
# Epoch:  3 | Iteration 207/374 | Batch Loss = 0.232585
# Epoch:  3 | Iteration 208/374 | Batch Loss = 0.159136
# Epoch:  3 | Iteration 209/374 | Batch Loss = 0.155986
# Epoch:  3 | Iteration 210/374 | Batch Loss = 0.207052
# Epoch:  3 | Iteration 211/374 | Batch Loss = 0.169761
# Epoch:  3 | Iteration 212/374 | Batch Loss = 0.180345
# Epoch:  3 | Iteration 213/374 | Batch Loss = 0.207560
# Epoch:  3 | Iteration 214/374 | Batch Loss = 0.220614
# Epoch:  3 | Iteration 215/374 | Batch Loss = 0.116716
# Epoch:  3 | Iteration 216/374 | Batch Loss = 0.171872
# Epoch:  3 | Iteration 217/374 | Batch Loss = 0.088947
# Epoch:  3 | Iteration 218/374 | Batch Loss = 0.145441
# Epoch:  3 | Iteration 219/374 | Batch Loss = 0.233419
# Epoch:  3 | Iteration 220/374 | Batch Loss = 0.139932
# Epoch:  3 | Iteration 221/374 | Batch Loss = 0.259325
# Epoch:  3 | Iteration 222/374 | Batch Loss = 0.266637
# Epoch:  3 | Iteration 223/374 | Batch Loss = 0.178714
# Epoch:  3 | Iteration 224/374 | Batch Loss = 0.150415
# Epoch:  3 | Iteration 225/374 | Batch Loss = 0.098874
# Epoch:  3 | Iteration 226/374 | Batch Loss = 0.188423
# Epoch:  3 | Iteration 227/374 | Batch Loss = 0.196170
# Epoch:  3 | Iteration 228/374 | Batch Loss = 0.279874
# Epoch:  3 | Iteration 229/374 | Batch Loss = 0.140203
# Epoch:  3 | Iteration 230/374 | Batch Loss = 0.143960
# Epoch:  3 | Iteration 231/374 | Batch Loss = 0.187626
# Epoch:  3 | Iteration 232/374 | Batch Loss = 0.190481
# Epoch:  3 | Iteration 233/374 | Batch Loss = 0.149428
# Epoch:  3 | Iteration 234/374 | Batch Loss = 0.197643
# Epoch:  3 | Iteration 235/374 | Batch Loss = 0.122852
# Epoch:  3 | Iteration 236/374 | Batch Loss = 0.294806
# Epoch:  3 | Iteration 237/374 | Batch Loss = 0.238954
# Epoch:  3 | Iteration 238/374 | Batch Loss = 0.128593
# Epoch:  3 | Iteration 239/374 | Batch Loss = 0.088083
# Epoch:  3 | Iteration 240/374 | Batch Loss = 0.330162
# Epoch:  3 | Iteration 241/374 | Batch Loss = 0.238029
# Epoch:  3 | Iteration 242/374 | Batch Loss = 0.089361
# Epoch:  3 | Iteration 243/374 | Batch Loss = 0.161878
# Epoch:  3 | Iteration 244/374 | Batch Loss = 0.225136
# Epoch:  3 | Iteration 245/374 | Batch Loss = 0.216373
# Epoch:  3 | Iteration 246/374 | Batch Loss = 0.105810
# Epoch:  3 | Iteration 247/374 | Batch Loss = 0.211349
# Epoch:  3 | Iteration 248/374 | Batch Loss = 0.171627
# Epoch:  3 | Iteration 249/374 | Batch Loss = 0.124274
# Epoch:  3 | Iteration 250/374 | Batch Loss = 0.176381
# Epoch:  3 | Iteration 251/374 | Batch Loss = 0.162305
# Epoch:  3 | Iteration 252/374 | Batch Loss = 0.182634
# Epoch:  3 | Iteration 253/374 | Batch Loss = 0.173308
# Epoch:  3 | Iteration 254/374 | Batch Loss = 0.139721
# Epoch:  3 | Iteration 255/374 | Batch Loss = 0.272672
# Epoch:  3 | Iteration 256/374 | Batch Loss = 0.173178
# Epoch:  3 | Iteration 257/374 | Batch Loss = 0.172898
# Epoch:  3 | Iteration 258/374 | Batch Loss = 0.161203
# Epoch:  3 | Iteration 259/374 | Batch Loss = 0.208042
# Epoch:  3 | Iteration 260/374 | Batch Loss = 0.144544
# Epoch:  3 | Iteration 261/374 | Batch Loss = 0.159156
# Epoch:  3 | Iteration 262/374 | Batch Loss = 0.161792
# Epoch:  3 | Iteration 263/374 | Batch Loss = 0.237433
# Epoch:  3 | Iteration 264/374 | Batch Loss = 0.167701
# Epoch:  3 | Iteration 265/374 | Batch Loss = 0.242905
# Epoch:  3 | Iteration 266/374 | Batch Loss = 0.231685
# Epoch:  3 | Iteration 267/374 | Batch Loss = 0.172043
# Epoch:  3 | Iteration 268/374 | Batch Loss = 0.093018
# Epoch:  3 | Iteration 269/374 | Batch Loss = 0.168895
# Epoch:  3 | Iteration 270/374 | Batch Loss = 0.132424
# Epoch:  3 | Iteration 271/374 | Batch Loss = 0.163761
# Epoch:  3 | Iteration 272/374 | Batch Loss = 0.118996
# Epoch:  3 | Iteration 273/374 | Batch Loss = 0.153601
# Epoch:  3 | Iteration 274/374 | Batch Loss = 0.213087
# Epoch:  3 | Iteration 275/374 | Batch Loss = 0.218627
# Epoch:  3 | Iteration 276/374 | Batch Loss = 0.279428
# Epoch:  3 | Iteration 277/374 | Batch Loss = 0.135822
# Epoch:  3 | Iteration 278/374 | Batch Loss = 0.176284
# Epoch:  3 | Iteration 279/374 | Batch Loss = 0.148540
# Epoch:  3 | Iteration 280/374 | Batch Loss = 0.171535
# Epoch:  3 | Iteration 281/374 | Batch Loss = 0.294277
# Epoch:  3 | Iteration 282/374 | Batch Loss = 0.113802
# Epoch:  3 | Iteration 283/374 | Batch Loss = 0.183375
# Epoch:  3 | Iteration 284/374 | Batch Loss = 0.157756
# Epoch:  3 | Iteration 285/374 | Batch Loss = 0.162323
# Epoch:  3 | Iteration 286/374 | Batch Loss = 0.201169
# Epoch:  3 | Iteration 287/374 | Batch Loss = 0.179740
# Epoch:  3 | Iteration 288/374 | Batch Loss = 0.111753
# Epoch:  3 | Iteration 289/374 | Batch Loss = 0.193142
# Epoch:  3 | Iteration 290/374 | Batch Loss = 0.126660
# Epoch:  3 | Iteration 291/374 | Batch Loss = 0.139035
# Epoch:  3 | Iteration 292/374 | Batch Loss = 0.182457
# Epoch:  3 | Iteration 293/374 | Batch Loss = 0.135965
# Epoch:  3 | Iteration 294/374 | Batch Loss = 0.161500
# Epoch:  3 | Iteration 295/374 | Batch Loss = 0.108630
# Epoch:  3 | Iteration 296/374 | Batch Loss = 0.090293
# Epoch:  3 | Iteration 297/374 | Batch Loss = 0.145560
# Epoch:  3 | Iteration 298/374 | Batch Loss = 0.181301
# Epoch:  3 | Iteration 299/374 | Batch Loss = 0.191701
# Epoch:  3 | Iteration 300/374 | Batch Loss = 0.163101
# Epoch:  3 | Iteration 301/374 | Batch Loss = 0.151940
# Epoch:  3 | Iteration 302/374 | Batch Loss = 0.150685
# Epoch:  3 | Iteration 303/374 | Batch Loss = 0.178586
# Epoch:  3 | Iteration 304/374 | Batch Loss = 0.296916
# Epoch:  3 | Iteration 305/374 | Batch Loss = 0.178226
# Epoch:  3 | Iteration 306/374 | Batch Loss = 0.239234
# Epoch:  3 | Iteration 307/374 | Batch Loss = 0.252978
# Epoch:  3 | Iteration 308/374 | Batch Loss = 0.156637
# Epoch:  3 | Iteration 309/374 | Batch Loss = 0.185985
# Epoch:  3 | Iteration 310/374 | Batch Loss = 0.240725
# Epoch:  3 | Iteration 311/374 | Batch Loss = 0.230244
# Epoch:  3 | Iteration 312/374 | Batch Loss = 0.179518
# Epoch:  3 | Iteration 313/374 | Batch Loss = 0.075671
# Epoch:  3 | Iteration 314/374 | Batch Loss = 0.181721
# Epoch:  3 | Iteration 315/374 | Batch Loss = 0.165587
# Epoch:  3 | Iteration 316/374 | Batch Loss = 0.142817
# Epoch:  3 | Iteration 317/374 | Batch Loss = 0.175099
# Epoch:  3 | Iteration 318/374 | Batch Loss = 0.130600
# Epoch:  3 | Iteration 319/374 | Batch Loss = 0.183050
# Epoch:  3 | Iteration 320/374 | Batch Loss = 0.145581
# Epoch:  3 | Iteration 321/374 | Batch Loss = 0.158308
# Epoch:  3 | Iteration 322/374 | Batch Loss = 0.135723
# Epoch:  3 | Iteration 323/374 | Batch Loss = 0.219290
# Epoch:  3 | Iteration 324/374 | Batch Loss = 0.346542
# Epoch:  3 | Iteration 325/374 | Batch Loss = 0.127761
# Epoch:  3 | Iteration 326/374 | Batch Loss = 0.165554
# Epoch:  3 | Iteration 327/374 | Batch Loss = 0.057357
# Epoch:  3 | Iteration 328/374 | Batch Loss = 0.200022
# Epoch:  3 | Iteration 329/374 | Batch Loss = 0.151724
# Epoch:  3 | Iteration 330/374 | Batch Loss = 0.243430
# Epoch:  3 | Iteration 331/374 | Batch Loss = 0.239870
# Epoch:  3 | Iteration 332/374 | Batch Loss = 0.235799
# Epoch:  3 | Iteration 333/374 | Batch Loss = 0.141630
# Epoch:  3 | Iteration 334/374 | Batch Loss = 0.274886
# Epoch:  3 | Iteration 335/374 | Batch Loss = 0.164694
# Epoch:  3 | Iteration 336/374 | Batch Loss = 0.101015
# Epoch:  3 | Iteration 337/374 | Batch Loss = 0.176511
# Epoch:  3 | Iteration 338/374 | Batch Loss = 0.178091
# Epoch:  3 | Iteration 339/374 | Batch Loss = 0.138254
# Epoch:  3 | Iteration 340/374 | Batch Loss = 0.075927
# Epoch:  3 | Iteration 341/374 | Batch Loss = 0.219066
# Epoch:  3 | Iteration 342/374 | Batch Loss = 0.118668
# Epoch:  3 | Iteration 343/374 | Batch Loss = 0.337971
# Epoch:  3 | Iteration 344/374 | Batch Loss = 0.133835
# Epoch:  3 | Iteration 345/374 | Batch Loss = 0.096529
# Epoch:  3 | Iteration 346/374 | Batch Loss = 0.151166
# Epoch:  3 | Iteration 347/374 | Batch Loss = 0.192006
# Epoch:  3 | Iteration 348/374 | Batch Loss = 0.208677
# Epoch:  3 | Iteration 349/374 | Batch Loss = 0.153093
# Epoch:  3 | Iteration 350/374 | Batch Loss = 0.136077
# Epoch:  3 | Iteration 351/374 | Batch Loss = 0.219064
# Epoch:  3 | Iteration 352/374 | Batch Loss = 0.093294
# Epoch:  3 | Iteration 353/374 | Batch Loss = 0.192484
# Epoch:  3 | Iteration 354/374 | Batch Loss = 0.136883
# Epoch:  3 | Iteration 355/374 | Batch Loss = 0.082531
# Epoch:  3 | Iteration 356/374 | Batch Loss = 0.118782
# Epoch:  3 | Iteration 357/374 | Batch Loss = 0.213354
# Epoch:  3 | Iteration 358/374 | Batch Loss = 0.140896
# Epoch:  3 | Iteration 359/374 | Batch Loss = 0.200432
# Epoch:  3 | Iteration 360/374 | Batch Loss = 0.083451
# Epoch:  3 | Iteration 361/374 | Batch Loss = 0.153974
# Epoch:  3 | Iteration 362/374 | Batch Loss = 0.251734
# Epoch:  3 | Iteration 363/374 | Batch Loss = 0.152055
# Epoch:  3 | Iteration 364/374 | Batch Loss = 0.136609
# Epoch:  3 | Iteration 365/374 | Batch Loss = 0.238199
# Epoch:  3 | Iteration 366/374 | Batch Loss = 0.167138
# Epoch:  3 | Iteration 367/374 | Batch Loss = 0.148742
# Epoch:  3 | Iteration 368/374 | Batch Loss = 0.123879
# Epoch:  3 | Iteration 369/374 | Batch Loss = 0.145004
# Epoch:  3 | Iteration 370/374 | Batch Loss = 0.068964
# Epoch:  3 | Iteration 371/374 | Batch Loss = 0.145012
# Epoch:  3 | Iteration 372/374 | Batch Loss = 0.209666
# Epoch:  3 | Iteration 373/374 | Batch Loss = 0.206523

# %%
evaluate(trainloader)
# Out:
# tensor(0.9355, device='cuda:0')

# %% [markdown]
# # Testing Begins

# %%
class imagePairsTest(torch.utils.data.Dataset):
    def __init__(self, root_dir, csv_file_dir, img_dir, transform = None):
        super(imagePairsTest, self).__init__()
        
        self.csv_file = pd.read_csv(os.path.join(root_dir, csv_file_dir))
        self.img_dir = img_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.csv_file)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img1_names = os.path.join(self.img_dir,self.csv_file.iloc[idx, 0])
        img2_names = os.path.join(self.img_dir, self.csv_file.iloc[idx, 1])
        
        # imread returns the numpy array of RGB values for the image. Shape = (H,W,3)
        image1 = io.imread(img1_names)
        image2 = io.imread(img2_names)
        
        sample = (image1, image2)

        if self.transform:
            sample = self.transform(sample)

        return sample

# Defining Image transforms - Image Preprocessing

# Rescaling Pair of Images together
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]

        h, w = image1.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        image1 = skimage.transform.resize(image1, (new_h, new_w))
        
        
        h, w = image2.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        image2 = skimage.transform.resize(image2, (new_h, new_w))

        return (image1, image2)


class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = torch.randint(0, h - new_h)
        left = torch.randint(0, w - new_w)

        image1 = image1[top: top + new_h, left: left + new_w]
        image2 = image2[top: top + new_h, left: left + new_w]

        return (image1, image2)

class Normalize(object):
    def __init__(self, mean = 127.5, std = 128.0):
        self.mean = mean
        self.std = std
    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]
        image1 = (image1-self.mean)/self.std
        image2 = (image2-self.mean)/self.std
        return (image1, image2)

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image1, image2 = sample[0], sample[1]

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C x H x W
        image1 = image1.transpose((2, 0, 1))
        image2 = image2.transpose((2, 0, 1))
        return (torch.tensor(image1.copy(), dtype = torch.float32).contiguous(),
                torch.tensor(image2.copy(), dtype = torch.float32).contiguous())

# %%
testset = imagePairsTest(root_dir = ROOT_DIR, csv_file_dir= TEST_DIR,
                     img_dir = '/content/cropped', 
                     transform = transforms.Compose([Normalize(),ToTensor()]))

# %%
batch_size = 64
testloader = torch.utils.data.DataLoader(testset, batch_size = batch_size, shuffle = False)

# %%
predictions_list = []

def test_predict(loader):
    decoder.eval()
    with torch.no_grad():
        for batch in loader:
            # Passing it via final encoder to get predictions
            y_pred = decoder(batch[0].to(device), batch[1].to(device))
            y_pred = y_pred.argmax(dim=1).cpu().detach().numpy()
            predictions_list.extend(list(y_pred))
            
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

# %%
df_test = pd.read_csv(os.path.join(ROOT_DIR, TEST_DIR))

# %%
test_predict(testloader)

# %%
df_test['label_pred'] = predictions_list

# %%
df_test
# Out:
#                   image1              image2  label_pred
# 0     84770376235978.jpg  70098827925517.jpg           0
# 1     51285551988172.jpg  40352160634341.jpg           1
# 2     92104157409800.jpg  43993355472481.jpg           1
# 3     17278801258247.jpg  39952763632406.jpg           0
# 4     69669552075188.jpg  11563244873988.jpg           0
# ...                  ...                 ...         ...
# 4992  30470682361984.jpg  31915544799803.jpg           1
# 4993  38633214403572.jpg  17760910482671.jpg           0
# 4994  66870453878736.jpg  76054148475027.jpg           0
# 4995  25801526428363.jpg  47928524608159.jpg           1
# 4996  85942797925866.jpg  46795501393497.jpg           0
#
# [4997 rows x 3 columns]

# %%
df_test.to_csv('predictions.csv')

# %% [markdown]
# mtcnn(trainset[1][0], save_path = '../content/cropped/im.jpg')

# %% [markdown]
# from facenet_pytorch import MTCNN, InceptionResnetV1
#
# batch_size = 64
# image1_batch = []
# image2_batch = []
#
# # Batch transformation of all images into Tensors representing the Facial Area
# for i in range(len(df)):
#     img1 = trainset[i][0]
#     img2 = trainset[i][1]
#     label = trainset[i][2]
#
#     image1_batch.append(img1)
#     image2_batch.append(img2)
#     label_batch.append(label)
#
#     if (i+1)%batch_size == 0 or i==len(df)-1:
#         faces1.extend(mtcnn(image1_batch))
#         faces2.extend(mtcnn(image2_batch))
#         image1_batch, image2_batch = [], []
